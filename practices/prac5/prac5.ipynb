# %%
try:
    import google.colab
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB = True
except:
    COLAB = False

# !pip install gymnasium==0.29.1 vizdoom==1.2.4 wandb==0.19.1

# %%
import json
import math
import random
import sys
import os
import time
from collections import deque
from typing import Dict, Type, Any, Tuple, NamedTuple, Optional, Union, Generator, List

import gymnasium as gym
import gymnasium.spaces as spaces
from gymnasium.vector import AsyncVectorEnv, SyncVectorEnv
from gymnasium.wrappers import ResizeObservation, GrayScaleObservation, RecordEpisodeStatistics, TransformReward, \
    FrameStack
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn.functional as F
from torch import nn
from torch.distributions import Categorical
import vizdoom
from vizdoom import gymnasium_wrapper

try:
    import wandb
    WANDB_IS_AVAILABLE = True
except ImportError:
    WANDB_IS_AVAILABLE = False

os.environ["WANDB_API_KEY"] = "e97ffa4c776cbfb2c0fc0c8b5c97e875139c1d42"

# %% [markdown]
# # Градиент стратегии: REINFORCE
#
# Обозначения:
# - $s$ - состояние, $r$ - вознаграждение, $a$ - действие
# - Условное распределение действий $\pi(a | s)$ - стратегия агента
# - $\tau$ - траектория: $(s_0, r_0, a_0), \dots, (s_T, r_T, a_T)$
# - Отдача $G(\tau) = \sum_{t = 0} ^ T r_t \gamma ^ t$
# - $G_t = r_t + r_{t + 1} \gamma + \dots + r_{T} \gamma ^ {T - t}$
# - Функция полезности состояний: $V(s_{t}) = \mathbb{E}[G_t]$
# - Функция полезности действий: $Q(s_t, a_t) = \mathbb{E}[r_t + \gamma V(s_{t + 1}) | a_t]$
#
# В некоторых задачах для нахождения удовлетворительной стратегии необязательно в точности знать структуру всей среды. Например, в задаче поднятия кубика робототехнической рукой вместо точной аппроксимации полезности $Q(s,a)$ достаточно знать, что выгоднее: двигаться вправо, если кубик справа, и влево в ином случае. С этим же наблюдением связано и предположение, что задача поиска удовлетворительной стратегии проще, нежели задача точной оценки функции полезности.
#
# В данном семинаре познакомимся с простейшим методом прямой оптимизации стратегии REINFORCE, в котором параметры, задающие вероятностную стратегию, изменяются в соответствии с градиентом математического ожидания отдач:
#
# $$J(\theta)= \mathbb{E}[G(\tau)],$$
#
# $$\theta \leftarrow \theta +\alpha \nabla_{\theta} J(\theta),$$
#
# В первом выражении математическое ожидание берется по распределениям начальных состояний, вероятностным функциям переходов и вознаграждений среды, а также по вероятностной стратегии агента $\pi_\theta$. Благодаря теореме о существовании стационарного распределения марковской цепи, это выражение может быть переписано через стационарное распределение $d^\pi$ посещения состояний в среде:
#
# $$J(\theta)= \mathbb{E}_{s \sim d^\pi}[V^{\pi}(s)] = \mathbb{E}_{s \sim d^\pi, a \sim \pi(s)} [Q^{\pi}(s, a)] =: \mathbb{E}_\pi [Q^{\pi}(s, a)].$$
#
# Метод REINFORCE также использует теорему о градиенте стратегии, на основе которой построено целое семейство алгоритмов прямой оптимизации стратегии и актор-критиков. Теорема о градиенте стратегии связывает градиент целевой функции $J$ и градиент самой стратегии:
#
# $$\nabla_\theta J(\theta) = \mathbb{E}_\pi [Q^\pi(s, a) \nabla_\theta \ln \pi_\theta(a \vert s)]$$
#
# Для оценки полезности действий $Q^\pi(s, a)$ REINFORCE использует несмещенную Монте-Карло оценку на основе полученных в среде отдач $G_t$ (за некоторое фиксированное число эпизодов в среде). С учетом этого обновление весов осуществляется по правилу:
#
# $$\nabla_\theta J(\theta) = \mathbb{E}_\pi [G_t \nabla_\theta \ln \pi_\theta(a_t \vert s_t)]$$
#
# Более подробное (но все равно короткое) описание градиента стратегии, и в частности REINFORCE, можно посмотреть в [блоге Lilian Weng из OpenAI](https://lilianweng.github.io/posts/2018-04-08-policy-gradient/#policy-gradient), либо полноценно разобраться в соответствующей секции классического учебника Саттона и Барто.

# %% [markdown]
# ### Environment: Vizdoom
# Среда для экспериментов: **Vizdoom**. Задача: **VizdoomCorridor-v0**.
#
# Карта представляет собой коридор со стреляющими противниками по обеим сторонам. Зелёная броня размещена на противоположном конце коридора. Цель агента — добраться до предмета. Награда пропорциональна (отрицательна или положительна) изменению расстояния между игроком и жилетом.
# - Вознаграждение: +dX за приближение к броне, -dX за отдаление от брони, -100 за смерть.
# - Агенту доступны 7 действий: движение вперед/назад/влево/вправо, поворот влево/вправо, стрельба.
# - Ограничение по времени: 2100 шагов
#
# Для ускорения обучения агента рассматриваем самый простой уровень сложности `doom_skill = 1`.

# %%
def create_vizdoom_config(verbose=False):
    # Создаёт файл сценария VizdoomCorridor с уровнем сложности doom_skill = 1

    deadly_corridor_doom_skill_1 = """
    # Lines starting with # are treated as comments (or with whitespaces+#).
    # It doesn't matter if you use capital letters or not.
    # It doesn't matter if you use underscore or camel notation for keys, e.g. episode_timeout is the same as episodeTimeout.
    """
    deadly_corridor_doom_skill_1 += f"\ndoom_scenario_path = {os.path.relpath(os.path.dirname(vizdoom.__file__))}/scenarios/deadly_corridor.wad\n"
    deadly_corridor_doom_skill_1 += """
    # Skill 5 is recommended for the scenario to be a challenge.
    doom_skill = 1

    # Rewards
    death_penalty = 100
    #living_reward = 0

    # Rendering options
    screen_resolution = RES_320X240
    screen_format = CRCGCB
    render_hud = true
    render_crosshair = false
    render_weapon = true
    render_decals = false
    render_particles = false
    window_visible = true

    episode_timeout = 2100

    # Available buttons
    available_buttons =
      {
        MOVE_LEFT
        MOVE_RIGHT
        ATTACK
        MOVE_FORWARD
        MOVE_BACKWARD
        TURN_LEFT
        TURN_RIGHT
      }

    # Game variables that will be in the state
    available_game_variables = { HEALTH }

    mode = PLAYER
    """

    config_file_name = f'deadly_corridor_doom-skill-1.cfg'
    with open(config_file_name, 'w') as file_obj:
        print(deadly_corridor_doom_skill_1, file=file_obj)

    if verbose:
        print(deadly_corridor_doom_skill_1)

    return os.path.realpath(config_file_name)


def source_env_info():
    config_file_path = create_vizdoom_config()
    env = gym.make('VizdoomCorridor-v0', **{'scenario_file': config_file_path})
    obs, _ = env.reset()
    plt.imshow(obs['screen'])
    plt.show()
    print(env.env.env.spec.kwargs)

source_env_info()
# Out:
# c:\Users\iRU\AppData\Local\Programs\Python\Python312\Lib\site-packages\vizdoom\gymnasium_wrapper\base_gymnasium_env.py:84: UserWarning: Detected screen format CRCGCB. Only RGB24 and GRAY8 are supported in the Gymnasium wrapper. Forcing RGB24.
#   warnings.warn(
# {'scenario_file': 'C:\\Users\\iRU\\deadly_corridor_doom-skill-1.cfg'}

# %% [markdown]
# ### Wrappers

# %%
class ImageExtractorWrapper(gym.ObservationWrapper):
    def __init__(self, env):
        super().__init__(env)
        self.observation_space = env.observation_space['screen']

    def observation(self, observation: Dict) -> np.ndarray:
        return observation['screen']


def make_env():
    config_file_path = create_vizdoom_config()
    env = gym.make('VizdoomCorridor-v0', **{'scenario_file': config_file_path})
    env = ImageExtractorWrapper(env)
    env = GrayScaleObservation(env)
    env = ResizeObservation(env, shape=84)
    env = FrameStack(env, num_stack=3)
    env = RecordEpisodeStatistics(env)
    env = TransformReward(env, f=lambda reward: reward / 100.)

    return env


def wrapped_env_info():
    config_file_path = create_vizdoom_config()
    env = make_env()
    env.reset()
    terminated = False
    while not terminated:
        obs, reward, terminated, truncated, info = env.step(env.action_space.sample())

    fig, axes = plt.subplots(1, 3, figsize=(12, 3))
    for ax, frame in zip(axes, obs):
        ax.imshow(frame, cmap='gray')

    print('Наблюдение - стек из 3х последовательных изображений 84х84 в оттенках серого, shape:', obs.shape)
    plt.show()
    print('info на последнем шаге содержит статистику эпизода: r - суммарное вознаграждение, l - длина эпизода, t - продолжительность эпизода в секундах\n', info)

DEMO_WRAPPED_ENV = True
if DEMO_WRAPPED_ENV:
    wrapped_env_info()
# Out:
# Наблюдение - стек из 3х последовательных изображений 84х84 в оттенках серого, shape: (3, 84, 84)
# info на последнем шаге содержит статистику эпизода: r - суммарное вознаграждение, l - длина эпизода, t - продолжительность эпизода в секундах
#  {'episode': {'r': array([-87.40965], dtype=float32), 'l': array([436], dtype=int32), 't': array([1.476562], dtype=float32)}}

# %% [markdown]
# ### Misc

# %%
def set_seed_everywhere(seed: int, using_cuda: bool = False) -> None:
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)

    if using_cuda:
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False

# %% [markdown]
# # 1 REINFORCE

# %% [markdown]
# ### Policy
# Основные компоненты ReinforcePolicy:
# - `features_extractor` - свёрточный энкодер, кодирующий изображения в латентный вектор
# - `action_net` - полносвязный слой, который выдаёт логиты действий для предсказания вероятностей

# %% [markdown]
# ![policy](data:image/png;base64,...)

# %%
class Encoder(nn.Module):
    def __init__(
            self,
            observation_space: gym.Space,
            features_dim: int = 512,
    ) -> None:
        super().__init__()
        self.features_dim = features_dim
        n_input_channels = observation_space.shape[0]
        self.cnn = nn.Sequential(
            nn.Conv2d(n_input_channels, 32, kernel_size=8, stride=4, padding=0),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=4, stride=2, padding=0),
            nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=0),
            nn.ReLU(),
            nn.Flatten(),
        )

        with torch.no_grad():
            n_flatten = self.cnn(torch.as_tensor(observation_space.sample()[None]).float()).shape[1]

        self.linear = nn.Sequential(nn.Linear(n_flatten, features_dim), nn.ReLU())

    def forward(self, observations: torch.Tensor) -> torch.Tensor:
        return self.linear(self.cnn(observations))


class ReinforcePolicy(nn.Module):
    def __init__(self, observation_space: gym.Space, action_space: gym.Space, lr: float,
                 optimizer_class: Type[torch.optim.Optimizer] = torch.optim.RMSprop,
                 optimizer_kwargs: Dict[str, Any] = {'eps': 1e-5},):
        super().__init__()
        self.observation_space = observation_space
        self.action_space = action_space
        self.lr = lr
        self.optimizer_class = optimizer_class
        self.optimizer_kwargs = dict(optimizer_kwargs)
        self.features_extractor = self.make_features_extractor()
        self.action_net = nn.Linear(self.features_extractor.features_dim, self.action_space.n)
        self.optimizer = self.optimizer_class(self.parameters(), lr=self.lr, **self.optimizer_kwargs)

    def make_features_extractor(self):
        return Encoder(self.observation_space)

    def extract_features(self, obs: torch.Tensor) -> torch.Tensor:
        obs = obs.float() / 255.
        features = self.features_extractor(obs)

        return features

    def forward(self, obs: torch.Tensor, deterministic: bool = False) -> Dict[str, torch.Tensor]:
        features = self.extract_features(obs)

        action_logits = self.action_net(features)
        distribution = Categorical(logits=action_logits)
        actions = distribution.mode() if deterministic else distribution.sample()
        actions = actions.reshape((-1, *self.action_space.shape))

        return {'features': features, 'action': actions}

    def evaluate_actions(self, obs: torch.Tensor, actions_taken: torch.Tensor) -> Dict[str, torch.Tensor]:
        features = self.extract_features(obs)
        action_logits = self.action_net(features)
        distribution = Categorical(logits=action_logits)
        log_prob = distribution.log_prob(actions_taken)
        entropy = distribution.entropy()

        return {'features': features, 'log_prob': log_prob, 'entropy': entropy}

    def set_training_mode(self, mode: bool) -> None:
        self.train(mode)

# %% [markdown]
# ### Buffer
# В буфере хранятся траектории, собранные агентом. Также в буфере производится вычисление частичных отдач по траекториям.

# %%
class BufferSamples(NamedTuple):
    observations: torch.Tensor
    actions: torch.Tensor
    returns: torch.Tensor


class Buffer:
    def __init__(
            self,
            gamma: float = 0.99,
            device: Union[torch.device, str] = "cpu",
    ):
        self.device = torch.device(device)
        self.gamma = gamma
        self.observations = None
        self.actions = None
        self.rewards = None
        self.returns = None

    def reset(self) -> None:
        self.observations = []
        self.actions = []
        self.rewards = []
        self.returns = None

    def size(self) -> int:
        return len(self.actions)

    def add(
            self,
            obs: np.ndarray,
            action: int,
            reward: float,
    ) -> None:
        self.observations.append(obs)
        self.actions.append(action)
        self.rewards.append(reward)

    def to_torch(self, array: np.ndarray) -> torch.Tensor:
        return torch.tensor(array, device=self.device)

    def _get_samples(
            self,
            batch_inds: np.ndarray,
    ) -> BufferSamples:
        observations = self.to_torch(self.observations[batch_inds])
        actions = self.to_torch(self.actions[batch_inds])
        returns = self.to_torch(self.returns[batch_inds])

        return BufferSamples(observations=observations, actions=actions, returns=returns)

    def get(self) -> BufferSamples:
        buffer_size = self.size()
        indices = np.random.permutation(buffer_size)
        self.observations = np.asarray(self.observations)
        self.actions = np.asarray(self.actions)
        self.returns = np.asarray(self.returns, dtype=np.float32)

        return self._get_samples(indices)

    def compute_returns(self) -> None:
        returns = [None] * len(self.rewards)
        reward_to_go = 0
        for step in reversed(range(len(self.rewards))):
            reward_to_go = self.rewards[step] + self.gamma * reward_to_go
            returns[step] = reward_to_go

        self.returns = returns

# %% [markdown]
# ### Обучение стратегии по методу REINFORCE
# - Метод `learn`: реализует основной цикл RL-обучения: чередование фазы сбора данных (траекторий) агентом в среде - `collect_rollouts` и фазы обучения агента - `train`.
# - Метод `collect_rollouts`: агент выполняет действия в среде согласно текущей стратегии, собирая триплеты **<observation, action, reward>** в буфер
# - Метод `train`: обучение на собранных данных. Функция потерь состоит из двух слагаемых: градиент стратегии и энтропийная регуляризация. Энтропийная регуляризация делает стратегию более стохастичной, т.е. более устойчивой к шуму, помогает исследовать среду, предотвращает сходимость к субоптимальному решению (особенно в средах с дискретными действиями)

# %% [markdown]
# ![learn](data:image/png;base64,...)

# %% [markdown]
# ![reinforce](data:image/png;base64,...)

# %%
class Reinforce:
    def __init__(
            self,
            env: gym.Env,
            learning_rate: float = 2.5e-4,
            gamma: float = 0.99,
            ent_coef: float = 0.001,
            max_grad_norm: float = 0.5,
            stats_window_size: int = 10,
            policy_class: Type[ReinforcePolicy] = ReinforcePolicy,
            policy_kwargs: Optional[Dict[str, Any]] = None,
            buffer_class: Type[Buffer] = Buffer,
            buffer_kwargs: Optional[Dict[str, Any]] = None,
            seed: Optional[int] = None,
            device: Union[torch.device, str] = "cuda",
    ):
        self.device = device if isinstance(device, torch.device) else torch.device(device)
        print(f"Using {self.device} device")

        self.policy_kwargs = {} if policy_kwargs is None else policy_kwargs

        self.num_timesteps = 0
        self._num_timesteps_at_start = 0
        self._episode_num = 0
        self.seed = seed
        self.start_time = 0.0
        self.learning_rate = learning_rate
        self._last_obs = None
        self._stats_window_size = stats_window_size
        self.ep_info_buffer = deque(maxlen=self._stats_window_size)
        self._n_updates = 0

        self.observation_space = env.observation_space
        self.action_space = env.action_space
        self.env = env

        self.n_steps = None
        self.gamma = gamma
        self.ent_coef = ent_coef
        self.max_grad_norm = max_grad_norm
        self.log_dict = {}

        self.set_random_seed(self.seed)
        self.buffer_class = buffer_class
        self.buffer_kwargs = {} if buffer_kwargs is None else buffer_kwargs
        self.buffer = self.buffer_class(
            device=self.device,
            gamma=self.gamma,
            **self.buffer_kwargs,
        )
        self.policy_class = policy_class
        self.policy = self.policy_class(
            self.observation_space, self.action_space, self.learning_rate, **self.policy_kwargs
        )
        self.policy = self.policy.to(self.device)

    def _update_info_buffer(self, info: Dict[str, Any]) -> None:
        # Collect statistics
        assert self.ep_info_buffer is not None

        ep_info = info.get("episode")
        if ep_info is not None:
            self.ep_info_buffer.append(ep_info)

    def set_random_seed(self, seed: Optional[int] = None) -> None:
        if seed is None:
            return
        set_seed_everywhere(seed, using_cuda=self.device.type == torch.device("cuda").type)
        self.action_space.seed(seed)
        self.observation_space.seed(seed)

    def collect_rollouts(
            self,
            env,
            buffer: Buffer,
    ):
        self.policy.set_training_mode(False)
        self._last_obs, _ = self.env.reset()
        self._last_obs = np.array(self._last_obs)
        assert self._last_obs is not None, "No previous observation was provided"

        buffer.reset()
        terminated = False
        while not terminated:
            with torch.no_grad():
                obs_tensor = torch.as_tensor(self._last_obs, device=self.device)
                action = self.policy(obs_tensor.unsqueeze(0))['action']
            action = action.item()
            new_obs, reward, terminated, truncated, info = env.step(action)
            assert not truncated, 'Episode truncation must be off as we want to use Monte Carlo estimation'

            self.num_timesteps += 1
            self._episode_num += int(terminated)
            buffer.add(
                self._last_obs,
                action,
                reward,
            )

            self._last_obs = np.array(new_obs)
            self._update_info_buffer(info)

        buffer.compute_returns()

    def train(self) -> None:
        self.policy.set_training_mode(True)

        rollout_data = self.buffer.get()
        actions = rollout_data.actions.long()
        policy_output = self.policy.evaluate_actions(rollout_data.observations, actions)
        log_prob = policy_output['log_prob']
        entropy = policy_output['entropy']
        returns = rollout_data.returns

        # Policy gradient loss
        policy_loss = -(returns * log_prob).mean()

        # Entropy loss
        entropy = torch.mean(entropy)
        entropy_loss = -self.ent_coef * entropy

        loss = policy_loss + entropy_loss

        # Optimization step
        self.policy.optimizer.zero_grad()
        loss.backward()
        grad_norm = torch.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
        self.policy.optimizer.step()

        self._n_updates += 1

        self.log_dict = dict([
            ("train/entropy_loss", entropy_loss.item()), ("train/entropy", entropy.item()),
            ("train/policy_gradient_loss", policy_loss.item()), ("train/loss", loss.item()),
            ("train/grad_norm", grad_norm.item()), ("train/n_updates", self._n_updates)
        ])

    def get_current_mean_return(self) -> float:
        if len(self.ep_info_buffer) == 0:
            return -math.inf

        return np.mean(np.concatenate([ep_info["r"] for ep_info in self.ep_info_buffer])).item()

    def _dump_logs(self, iteration: int) -> None:
        assert self.ep_info_buffer is not None

        time_elapsed = max((time.time_ns() - self.start_time) / 1e9, sys.float_info.epsilon)
        fps = int((self.num_timesteps - self._num_timesteps_at_start) / time_elapsed)
        self.log_dict["time/iterations"] = iteration
        if len(self.ep_info_buffer) > 0 and len(self.ep_info_buffer[0]) > 0:
            self.log_dict["rollout/ep_rew_mean"] = self.get_current_mean_return()
            self.log_dict["rollout/ep_len_mean"] = np.mean(
                np.concatenate([ep_info["l"] for ep_info in self.ep_info_buffer])).item()

        self.log_dict["time/fps"] = fps
        self.log_dict["time/time_elapsed"] = int(time_elapsed)
        self.log_dict["global_step"] = self.num_timesteps
        self.log_dict["num_episodes"] = self._episode_num
        print(json.dumps(self.log_dict, sort_keys=True, indent=4))

        if WANDB_IS_AVAILABLE and wandb.run is not None:
            wandb.log(self.log_dict)

    def learn(
            self,
            max_timesteps: int,
            expected_return: float,
            log_interval: int = 1000,
            save_checkpoint_path: str = None,
            save_checkpoint_interval: int = 5000,
    ) -> None:
        assert self.env is not None

        self.start_time = time.time_ns()
        self.num_timesteps = 0
        self._episode_num = 0
        self._num_timesteps_at_start = 0
        log_interval = log_interval or math.inf
        if save_checkpoint_path is None or save_checkpoint_interval is None or not COLAB:
            save_checkpoint_interval = math.inf

        next_log_step = self.num_timesteps + log_interval
        next_save_step = self.num_timesteps + save_checkpoint_interval

        if self._last_obs is None:
            self._last_obs, _ = self.env.reset(seed=self.seed)

        iteration = 0
        while True:
            if self.get_current_mean_return() >= expected_return:
                print('Решено!')
                break

            if self.num_timesteps >= max_timesteps:
                print(f'Задача не решена за {max_timesteps} шагов')
                break

            self.collect_rollouts(self.env, self.buffer, )
            iteration += 1

            if self.num_timesteps >= next_log_step:
                assert self.ep_info_buffer is not None
                self._dump_logs(iteration)
                next_log_step += log_interval

            if self.num_timesteps >= next_save_step:
                next_save_step += save_checkpoint_interval
                checkpoint = {'policy': self.policy.state_dict(), 'optimizer': self.policy.optimizer.state_dict(),
                              'num_timesteps': self.num_timesteps, 'episode_num': self._episode_num,
                              'ep_info_buffer': self.ep_info_buffer}
                os.makedirs(save_checkpoint_path, exist_ok=True)
                torch.save(checkpoint, os.path.join(save_checkpoint_path, 'checkpoint.pt'))

            self.train()

# %%
def run_algorithm(algorithm_class, algorithm_kwargs, use_wandb, wandb_kwargs, learn_kwargs):
    env = make_env()
    model = algorithm_class(env, **algorithm_kwargs)
    if use_wandb:
        config = {}
        config.update(algorithm_kwargs)
        config.update(learn_kwargs)
        config.update(wandb_kwargs.get('config', {}))
        wandb_kwargs['config'] = config
        if wandb.run is not None:
            wandb.finish()

        wandb.init(**wandb_kwargs)

    model.learn(**learn_kwargs)
    if use_wandb:
        wandb.finish()

# %%
run_algorithm(
    algorithm_class=Reinforce,
    algorithm_kwargs=dict(seed=0, ),
    use_wandb=WANDB_IS_AVAILABLE,
    wandb_kwargs=dict(project='seminar_actor-critic', monitor_gym=True, name='reinforce'),
    learn_kwargs=dict(max_timesteps=50000, log_interval=1000, expected_return=2000, save_checkpoint_interval=1000,
                      save_checkpoint_path='/content/drive/My Drive/seminar_actor-critic/reinforce',)
)
# Out:
# Using cuda device
# C:\Users\iRU\AppData\Local\Temp\ipykernel_5084\3336005168.py:79: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   self._last_obs = np.array(self._last_obs)
# C:\Users\iRU\AppData\Local\Temp\ipykernel_5084\3336005168.py:100: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   self._last_obs = np.array(new_obs)
# {
#     "global_step": 1303,
#     "num_episodes": 3,
#     "rollout/ep_len_mean": 434.3333333333333,
#     "rollout/ep_rew_mean": -58.70725631713867,
#     "time/fps": 66,
#     "time/iterations": 3,
#     "time/time_elapsed": 19,
#     "train/entropy": 2.078981637954712,
#     "train/entropy_loss": -0.002078981837257743,
#     "train/grad_norm": 0.017130590975284576,
#     "train/loss": -0.18334105610847473,
#     "train/n_updates": 2,
#     "train/policy_gradient_loss": -0.1812620759010315
# }
# {
#     "global_step": 2129,
#     "num_episodes": 5,
#     "rollout/ep_len_mean": 425.8,
#     "rollout/ep_rew_mean": -52.0356330871582,
#     "time/fps": 68,
#     "time/iterations": 5,
#     "time/time_elapsed": 31,
#     "train/entropy": 2.078382730484009,
#     "train/entropy_loss": -0.0020783827640116215,
#     "train/grad_norm": 0.020274391397833824,
#     "train/loss": -0.1716112494468689,
#     "train/n_updates": 4,
#     "train/policy_gradient_loss": -0.1695328652858734
# }
# {
#     "global_step": 3262,
#     "num_episodes": 6,
#     "rollout/ep_len_mean": 543.6666666666666,
#     "rollout/ep_rew_mean": -62.00615310668945,
#     "time/fps": 67,
#     "time/iterations": 6,
#     "time/time_elapsed": 48,
#     "train/entropy": 2.0792808532714844,
#     "train/entropy_loss": -0.002079281024634838,
#     "train/grad_norm": 0.010885899886488914,
#     "train/loss": -0.21753457188606262,
#     "train/n_updates": 5,
#     "train/policy_gradient_loss": -0.2154552936553955
# }
# {
#     "global_step": 4322,
#     "num_episodes": 9,
#     "rollout/ep_len_mean": 480.22222222222223,
#     "rollout/ep_rew_mean": -74.3956298828125,
#     "time/fps": 69,
#     "time/iterations": 9,
#     "time/time_elapsed": 62,
#     "train/entropy": 2.079213857650757,
#     "train/entropy_loss": -0.002079213969409466,
#     "train/grad_norm": 0.029307447373867035,
#     "train/loss": -0.7571735978126526,
#     "train/n_updates": 8,
#     "train/policy_gradient_loss": -0.7550944089889526
# }
# {
#     "global_step": 5005,
#     "num_episodes": 11,
#     "rollout/ep_len_mean": 459.3,
#     "rollout/ep_rew_mean": -72.21192932128906,
#     "time/fps": 69,
#     "time/iterations": 11,
#     "time/time_elapsed": 72,
#     "train/entropy": 2.07887864112854,
#     "train/entropy_loss": -0.0020788786932826042,
#     "train/grad_norm": 0.02094390243291855,
#     "train/loss": -0.3919503688812256,
#     "train/n_updates": 10,
#     "train/policy_gradient_loss": -0.3898714780807495
# }
# {
#     "global_step": 7565,
#     "num_episodes": 13,
#     "rollout/ep_len_mean": 626.2,
#     "rollout/ep_rew_mean": -50.60826110839844,
#     "time/fps": 71,
#     "time/iterations": 13,
#     "time/time_elapsed": 106,
#     "train/entropy": 2.07900071144104,
#     "train/entropy_loss": -0.002079000696539879,
#     "train/grad_norm": 0.006801918614655733,
#     "train/loss": -0.3285099267959595,
#     "train/n_updates": 12,
#     "train/policy_gradient_loss": -0.32643091678619385
# }
# {
#     "global_step": 7868,
#     "num_episodes": 14,
#     "rollout/ep_len_mean": 613.0,
#     "rollout/ep_rew_mean": -55.54765701293945,
#     "time/fps": 71,
#     "time/iterations": 14,
#     "time/time_elapsed": 110,
#     "train/entropy": 2.0788755416870117,
#     "train/entropy_loss": -0.0020788756664842367,
#     "train/grad_norm": 0.011352777481079102,
#     "train/loss": 0.20267216861248016,
#     "train/n_updates": 13,
#     "train/policy_gradient_loss": 0.20475104451179504
# }
# {
#     "global_step": 8313,
#     "num_episodes": 15,
#     "rollout/ep_len_mean": 618.4,
#     "rollout/ep_rew_mean": -54.416038513183594,
#     "time/fps": 71,
#     "time/iterations": 15,
#     "time/time_elapsed": 116,
#     "train/entropy": 2.0784952640533447,
#     "train/entropy_loss": -0.00207849545404315,
#     "train/grad_norm": 0.042938318103551865,
#     "train/loss": -0.9031103253364563,
#     "train/n_updates": 14,
#     "train/policy_gradient_loss": -0.9010318517684937
# }
# {
#     "global_step": 9095,
#     "num_episodes": 18,
#     "rollout/ep_len_mean": 517.9,
#     "rollout/ep_rew_mean": -0.6007674932479858,
#     "time/fps": 70,
#     "time/iterations": 18,
#     "time/time_elapsed": 128,
#     "train/entropy": 1.7036828994750977,
#     "train/entropy_loss": -0.0017036829376593232,
#     "train/grad_norm": 0.35621559619903564,
#     "train/loss": 1.406090497970581,
#     "train/n_updates": 17,
#     "train/policy_gradient_loss": 1.4077942371368408
# }
# {
#     "global_step": 10468,
#     "num_episodes": 21,
#     "rollout/ep_len_mean": 546.3,
#     "rollout/ep_rew_mean": 51.82224655151367,
#     "time/fps": 71,
#     "time/iterations": 21,
#     "time/time_elapsed": 145,
#     "train/entropy": 2.0503811836242676,
#     "train/entropy_loss": -0.002050381386652589,
#     "train/grad_norm": 0.031088130548596382,
#     "train/loss": 0.10345858335494995,
#     "train/n_updates": 20,
#     "train/policy_gradient_loss": 0.1055089682340622
# }
# {
#     "global_step": 11107,
#     "num_episodes": 23,
#     "rollout/ep_len_mean": 354.2,
#     "rollout/ep_rew_mean": 67.33329772949219,
#     "time/fps": 72,
#     "time/iterations": 23,
#     "time/time_elapsed": 154,
#     "train/entropy": 1.9888339042663574,
#     "train/entropy_loss": -0.0019888340029865503,
#     "train/grad_norm": 0.0910293310880661,
#     "train/loss": 0.8158510327339172,
#     "train/n_updates": 22,
#     "train/policy_gradient_loss": 0.8178398609161377
# }
# {
#     "global_step": 12084,
#     "num_episodes": 27,
#     "rollout/ep_len_mean": 331.3,
#     "rollout/ep_rew_mean": 110.6963119506836,
#     "time/fps": 71,
#     "time/iterations": 27,
#     "time/time_elapsed": 167,
#     "train/entropy": 2.026735782623291,
#     "train/entropy_loss": -0.002026735804975033,
#     "train/grad_norm": 0.09974764287471771,
#     "train/loss": -0.03634878993034363,
#     "train/n_updates": 26,
#     "train/policy_gradient_loss": -0.03432205319404602
# }
# {
#     "global_step": 13266,
#     "num_episodes": 32,
#     "rollout/ep_len_mean": 243.9,
#     "rollout/ep_rew_mean": 121.1861572265625,
#     "time/fps": 71,
#     "time/iterations": 32,
#     "time/time_elapsed": 184,
#     "train/entropy": 2.059734582901001,
#     "train/entropy_loss": -0.002059734659269452,
#     "train/grad_norm": 0.06877818703651428,
#     "train/loss": 0.21215413510799408,
#     "train/n_updates": 31,
#     "train/policy_gradient_loss": 0.21421386301517487
# }
# {
#     "global_step": 14067,
#     "num_episodes": 35,
#     "rollout/ep_len_mean": 247.1,
#     "rollout/ep_rew_mean": 69.88252258300781,
#     "time/fps": 72,
#     "time/iterations": 35,
#     "time/time_elapsed": 194,
#     "train/entropy": 2.047088623046875,
#     "train/entropy_loss": -0.002047088695690036,
#     "train/grad_norm": 0.04425209015607834,
#     "train/loss": 0.06549540162086487,
#     "train/n_updates": 34,
#     "train/policy_gradient_loss": 0.06754249334335327
# }
# {
#     "global_step": 15051,
#     "num_episodes": 39,
#     "rollout/ep_len_mean": 245.5,
#     "rollout/ep_rew_mean": 94.56980895996094,
#     "time/fps": 72,
#     "time/iterations": 39,
#     "time/time_elapsed": 208,
#     "train/entropy": 1.9770076274871826,
#     "train/entropy_loss": -0.0019770078361034393,
#     "train/grad_norm": 0.1505727916955948,
#     "train/loss": 1.0381892919540405,
#     "train/n_updates": 38,
#     "train/policy_gradient_loss": 1.0401662588119507
# }
# {
#     "global_step": 16252,
#     "num_episodes": 43,
#     "rollout/ep_len_mean": 274.2,
#     "rollout/ep_rew_mean": 336.71539306640625,
#     "time/fps": 72,
#     "time/iterations": 43,
#     "time/time_elapsed": 224,
#     "train/entropy": 1.0013775825500488,
#     "train/entropy_loss": -0.0010013775900006294,
#     "train/grad_norm": 1.2513906955718994,
#     "train/loss": 1.9089579582214355,
#     "train/n_updates": 42,
#     "train/policy_gradient_loss": 1.909959316253662
# }
# {
#     "global_step": 17162,
#     "num_episodes": 47,
#     "rollout/ep_len_mean": 259.8,
#     "rollout/ep_rew_mean": 513.4361572265625,
#     "time/fps": 72,
#     "time/iterations": 47,
#     "time/time_elapsed": 235,
#     "train/entropy": 1.0694459676742554,
#     "train/entropy_loss": -0.0010694459779188037,
#     "train/grad_norm": 0.951566219329834,
#     "train/loss": 1.585206151008606,
#     "train/n_updates": 46,
#     "train/policy_gradient_loss": 1.586275577545166
# }
# {
#     "global_step": 18051,
#     "num_episodes": 53,
#     "rollout/ep_len_mean": 179.9,
#     "rollout/ep_rew_mean": 479.931396484375,
#     "time/fps": 73,
#     "time/iterations": 53,
#     "time/time_elapsed": 245,
#     "train/entropy": 0.7254422903060913,
#     "train/entropy_loss": -0.000725442310795188,
#     "train/grad_norm": 1.7539979219436646,
#     "train/loss": 1.4650168418884277,
#     "train/n_updates": 52,
#     "train/policy_gradient_loss": 1.4657422304153442
# }
# {
#     "global_step": 19156,
#     "num_episodes": 60,
#     "rollout/ep_len_mean": 154.5,
#     "rollout/ep_rew_mean": 1281.610595703125,
#     "time/fps": 73,
#     "time/iterations": 60,
#     "time/time_elapsed": 259,
#     "train/entropy": 0.0954999178647995,
#     "train/entropy_loss": -9.549991955282167e-05,
#     "train/grad_norm": 1.620344877243042,
#     "train/loss": 0.5365840196609497,
#     "train/n_updates": 59,
#     "train/policy_gradient_loss": 0.5366795063018799
# }
# {
#     "global_step": 20058,
#     "num_episodes": 65,
#     "rollout/ep_len_mean": 175.1,
#     "rollout/ep_rew_mean": 1893.4326171875,
#     "time/fps": 73,
#     "time/iterations": 65,
#     "time/time_elapsed": 271,
#     "train/entropy": 0.17726951837539673,
#     "train/entropy_loss": -0.00017726952501107007,
#     "train/grad_norm": 1.516166090965271,
#     "train/loss": 0.7907978296279907,
#     "train/n_updates": 64,
#     "train/policy_gradient_loss": 0.7909750938415527
# }
# {
#     "global_step": 21072,
#     "num_episodes": 71,
#     "rollout/ep_len_mean": 171.9,
#     "rollout/ep_rew_mean": 1262.643310546875,
#     "time/fps": 74,
#     "time/iterations": 71,
#     "time/time_elapsed": 284,
#     "train/entropy": 0.3898106813430786,
#     "train/entropy_loss": -0.00038981070974841714,
#     "train/grad_norm": 2.7853338718414307,
#     "train/loss": 1.1101006269454956,
#     "train/n_updates": 70,
#     "train/policy_gradient_loss": 1.1104904413223267
# }
# {
#     "global_step": 22103,
#     "num_episodes": 76,
#     "rollout/ep_len_mean": 188.2,
#     "rollout/ep_rew_mean": 666.8220825195312,
#     "time/fps": 74,
#     "time/iterations": 76,
#     "time/time_elapsed": 297,
#     "train/entropy": 0.6942341923713684,
#     "train/entropy_loss": -0.0006942342151887715,
#     "train/grad_norm": 0.6059726476669312,
#     "train/loss": 0.005436064675450325,
#     "train/n_updates": 75,
#     "train/policy_gradient_loss": 0.006130299065262079
# }
# {
#     "global_step": 23402,
#     "num_episodes": 78,
#     "rollout/ep_len_mean": 281.3,
#     "rollout/ep_rew_mean": 400.1166687011719,
#     "time/fps": 74,
#     "time/iterations": 78,
#     "time/time_elapsed": 314,
#     "train/entropy": 0.6957691311836243,
#     "train/entropy_loss": -0.0006957691512070596,
#     "train/grad_norm": 0.38450029492378235,
#     "train/loss": -0.054209593683481216,
#     "train/n_updates": 77,
#     "train/policy_gradient_loss": -0.05351382493972778
# }
# {
#     "global_step": 24436,
#     "num_episodes": 81,
#     "rollout/ep_len_mean": 336.4,
#     "rollout/ep_rew_mean": 217.77059936523438,
#     "time/fps": 74,
#     "time/iterations": 81,
#     "time/time_elapsed": 329,
#     "train/entropy": 0.7280449271202087,
#     "train/entropy_loss": -0.0007280449499376118,
#     "train/grad_norm": 0.7975566983222961,
#     "train/loss": -0.7516703605651855,
#     "train/n_updates": 80,
#     "train/policy_gradient_loss": -0.7509422898292542
# }
# {
#     "global_step": 25059,
#     "num_episodes": 84,
#     "rollout/ep_len_mean": 351.1,
#     "rollout/ep_rew_mean": 134.76014709472656,
#     "time/fps": 74,
#     "time/iterations": 84,
#     "time/time_elapsed": 336,
#     "train/entropy": 0.6196002960205078,
#     "train/entropy_loss": -0.0006196003523655236,
#     "train/grad_norm": 1.0250318050384521,
#     "train/loss": -0.3957226574420929,
#     "train/n_updates": 83,
#     "train/policy_gradient_loss": -0.3951030671596527
# }
# {
#     "global_step": 26157,
#     "num_episodes": 91,
#     "rollout/ep_len_mean": 172.1,
#     "rollout/ep_rew_mean": 600.2896728515625,
#     "time/fps": 74,
#     "time/iterations": 91,
#     "time/time_elapsed": 350,
#     "train/entropy": 0.40497899055480957,
#     "train/entropy_loss": -0.00040497901500202715,
#     "train/grad_norm": 2.5322105884552,
#     "train/loss": 0.6766760349273682,
#     "train/n_updates": 90,
#     "train/policy_gradient_loss": 0.6770809888839722
# }
# {
#     "global_step": 27140,
#     "num_episodes": 96,
#     "rollout/ep_len_mean": 178.2,
#     "rollout/ep_rew_mean": 713.6466064453125,
#     "time/fps": 74,
#     "time/iterations": 96,
#     "time/time_elapsed": 364,
#     "train/entropy": 0.4685964584350586,
#     "train/entropy_loss": -0.00046859646681696177,
#     "train/grad_norm": 0.5991255044937134,
#     "train/loss": 0.6779173612594604,
#     "train/n_updates": 95,
#     "train/policy_gradient_loss": 0.6783859729766846
# }
# {
#     "global_step": 28127,
#     "num_episodes": 102,
#     "rollout/ep_len_mean": 174.3,
#     "rollout/ep_rew_mean": 705.8953247070312,
#     "time/fps": 74,
#     "time/iterations": 102,
#     "time/time_elapsed": 377,
#     "train/entropy": 0.2531825602054596,
#     "train/entropy_loss": -0.00025318257394246757,
#     "train/grad_norm": 2.711059331893921,
#     "train/loss": 0.5351948142051697,
#     "train/n_updates": 101,
#     "train/policy_gradient_loss": 0.5354480147361755
# }
# {
#     "global_step": 29165,
#     "num_episodes": 108,
#     "rollout/ep_len_mean": 169.4,
#     "rollout/ep_rew_mean": 1563.876708984375,
#     "time/fps": 74,
#     "time/iterations": 108,
#     "time/time_elapsed": 391,
#     "train/entropy": 0.07703243941068649,
#     "train/entropy_loss": -7.703244045842439e-05,
#     "train/grad_norm": 1.5280978679656982,
#     "train/loss": 0.4071556031703949,
#     "train/n_updates": 107,
#     "train/policy_gradient_loss": 0.4072326421737671
# }
# {
#     "global_step": 30209,
#     "num_episodes": 114,
#     "rollout/ep_len_mean": 177.2,
#     "rollout/ep_rew_mean": 1468.7818603515625,
#     "time/fps": 74,
#     "time/iterations": 114,
#     "time/time_elapsed": 405,
#     "train/entropy": 0.29482731223106384,
#     "train/entropy_loss": -0.0002948273322544992,
#     "train/grad_norm": 1.9552233219146729,
#     "train/loss": 0.6672415733337402,
#     "train/n_updates": 113,
#     "train/policy_gradient_loss": 0.6675363779067993
# }
# {
#     "global_step": 31133,
#     "num_episodes": 120,
#     "rollout/ep_len_mean": 166.4,
#     "rollout/ep_rew_mean": 1072.888427734375,
#     "time/fps": 74,
#     "time/iterations": 120,
#     "time/time_elapsed": 417,
#     "train/entropy": 0.3161812126636505,
#     "train/entropy_loss": -0.0003161812201142311,
#     "train/grad_norm": 0.6220437288284302,
#     "train/loss": 0.8715896010398865,
#     "train/n_updates": 119,
#     "train/policy_gradient_loss": 0.8719058036804199
# }
# {
#     "global_step": 32194,
#     "num_episodes": 126,
#     "rollout/ep_len_mean": 161.0,
#     "rollout/ep_rew_mean": 663.3929443359375,
#     "time/fps": 74,
#     "time/iterations": 126,
#     "time/time_elapsed": 432,
#     "train/entropy": 0.4458942115306854,
#     "train/entropy_loss": -0.00044589422759599984,
#     "train/grad_norm": 1.1089036464691162,
#     "train/loss": 1.0095399618148804,
#     "train/n_updates": 125,
#     "train/policy_gradient_loss": 1.0099858045578003
# }
# {
#     "global_step": 33141,
#     "num_episodes": 131,
#     "rollout/ep_len_mean": 186.9,
#     "rollout/ep_rew_mean": 504.4915466308594,
#     "time/fps": 74,
#     "time/iterations": 131,
#     "time/time_elapsed": 445,
#     "train/entropy": 0.6004292368888855,
#     "train/entropy_loss": -0.0006004292517900467,
#     "train/grad_norm": 2.0263350009918213,
#     "train/loss": 0.49357160925865173,
#     "train/n_updates": 130,
#     "train/policy_gradient_loss": 0.49417203664779663
# }
# {
#     "global_step": 34067,
#     "num_episodes": 137,
#     "rollout/ep_len_mean": 173.5,
#     "rollout/ep_rew_mean": 456.4872131347656,
#     "time/fps": 74,
#     "time/iterations": 137,
#     "time/time_elapsed": 457,
#     "train/entropy": 0.4534297585487366,
#     "train/entropy_loss": -0.00045342979137785733,
#     "train/grad_norm": 0.09045960754156113,
#     "train/loss": 0.7582278847694397,
#     "train/n_updates": 136,
#     "train/policy_gradient_loss": 0.7586812973022461
# }
# {
#     "global_step": 35035,
#     "num_episodes": 142,
#     "rollout/ep_len_mean": 171.9,
#     "rollout/ep_rew_mean": 483.0567321777344,
#     "time/fps": 74,
#     "time/iterations": 142,
#     "time/time_elapsed": 470,
#     "train/entropy": 0.45185616612434387,
#     "train/entropy_loss": -0.0004518561763688922,
#     "train/grad_norm": 1.5804963111877441,
#     "train/loss": 0.7299492359161377,
#     "train/n_updates": 141,
#     "train/policy_gradient_loss": 0.7304010987281799
# }
# {
#     "global_step": 36008,
#     "num_episodes": 148,
#     "rollout/ep_len_mean": 157.7,
#     "rollout/ep_rew_mean": 531.38916015625,
#     "time/fps": 74,
#     "time/iterations": 148,
#     "time/time_elapsed": 482,
#     "train/entropy": 0.5374140739440918,
#     "train/entropy_loss": -0.0005374141037464142,
#     "train/grad_norm": 7.564243316650391,
#     "train/loss": 1.2283642292022705,
#     "train/n_updates": 147,
#     "train/policy_gradient_loss": 1.2289016246795654
# }
# {
#     "global_step": 37093,
#     "num_episodes": 154,
#     "rollout/ep_len_mean": 175.2,
#     "rollout/ep_rew_mean": 1328.767578125,
#     "time/fps": 74,
#     "time/iterations": 154,
#     "time/time_elapsed": 496,
#     "train/entropy": 0.14940184354782104,
#     "train/entropy_loss": -0.00014940185064915568,
#     "train/grad_norm": 0.28871798515319824,
#     "train/loss": 0.5278951525688171,
#     "train/n_updates": 153,
#     "train/policy_gradient_loss": 0.528044581413269
# }
# {
#     "global_step": 38047,
#     "num_episodes": 160,
#     "rollout/ep_len_mean": 171.2,
#     "rollout/ep_rew_mean": 1293.327392578125,
#     "time/fps": 74,
#     "time/iterations": 160,
#     "time/time_elapsed": 507,
#     "train/entropy": 0.6034185290336609,
#     "train/entropy_loss": -0.0006034185644239187,
#     "train/grad_norm": 0.7054591774940491,
#     "train/loss": 0.6564216613769531,
#     "train/n_updates": 159,
#     "train/policy_gradient_loss": 0.6570250988006592
# }
# {
#     "global_step": 39090,
#     "num_episodes": 166,
#     "rollout/ep_len_mean": 165.8,
#     "rollout/ep_rew_mean": 948.10498046875,
#     "time/fps": 74,
#     "time/iterations": 166,
#     "time/time_elapsed": 522,
#     "train/entropy": 0.3029680550098419,
#     "train/entropy_loss": -0.000302968081086874,
#     "train/grad_norm": 5.626572608947754,
#     "train/loss": 1.9818122386932373,
#     "train/n_updates": 165,
#     "train/policy_gradient_loss": 1.9821151494979858
# }
# {
#     "global_step": 40114,
#     "num_episodes": 172,
#     "rollout/ep_len_mean": 178.0,
#     "rollout/ep_rew_mean": 1721.8115234375,
#     "time/fps": 74,
#     "time/iterations": 172,
#     "time/time_elapsed": 535,
#     "train/entropy": 0.09939618408679962,
#     "train/entropy_loss": -9.939618757925928e-05,
#     "train/grad_norm": 1.5747929811477661,
#     "train/loss": 0.6988154649734497,
#     "train/n_updates": 171,
#     "train/policy_gradient_loss": 0.6989148855209351
# }
# {
#     "global_step": 41077,
#     "num_episodes": 178,
#     "rollout/ep_len_mean": 165.4,
#     "rollout/ep_rew_mean": 1629.4635009765625,
#     "time/fps": 74,
#     "time/iterations": 178,
#     "time/time_elapsed": 549,
#     "train/entropy": 0.10883376002311707,
#     "train/entropy_loss": -0.00010883376671699807,
#     "train/grad_norm": 6.750992774963379,
#     "train/loss": 1.4739892482757568,
#     "train/n_updates": 177,
#     "train/policy_gradient_loss": 1.4740980863571167
# }
# {
#     "global_step": 42131,
#     "num_episodes": 184,
#     "rollout/ep_len_mean": 171.6,
#     "rollout/ep_rew_mean": 1616.505126953125,
#     "time/fps": 74,
#     "time/iterations": 184,
#     "time/time_elapsed": 562,
#     "train/entropy": 0.17379692196846008,
#     "train/entropy_loss": -0.00017379692872054875,
#     "train/grad_norm": 4.1276350021362305,
#     "train/loss": 1.742613434791565,
#     "train/n_updates": 183,
#     "train/policy_gradient_loss": 1.74278724193573
# }
# {
#     "global_step": 43147,
#     "num_episodes": 190,
#     "rollout/ep_len_mean": 168.8,
#     "rollout/ep_rew_mean": 1085.3460693359375,
#     "time/fps": 74,
#     "time/iterations": 190,
#     "time/time_elapsed": 575,
#     "train/entropy": 0.38310694694519043,
#     "train/entropy_loss": -0.00038310696254484355,
#     "train/grad_norm": 0.8509964942932129,
#     "train/loss": 0.9425036311149597,
#     "train/n_updates": 189,
#     "train/policy_gradient_loss": 0.9428867101669312
# }
# {
#     "global_step": 44112,
#     "num_episodes": 196,
#     "rollout/ep_len_mean": 170.0,
#     "rollout/ep_rew_mean": 943.04296875,
#     "time/fps": 74,
#     "time/iterations": 196,
#     "time/time_elapsed": 588,
#     "train/entropy": 0.2931045889854431,
#     "train/entropy_loss": -0.00029310458921827376,
#     "train/grad_norm": 0.7876156568527222,
#     "train/loss": 0.9302882552146912,
#     "train/n_updates": 195,
#     "train/policy_gradient_loss": 0.9305813312530518
# }
# {
#     "global_step": 45128,
#     "num_episodes": 202,
#     "rollout/ep_len_mean": 166.6,
#     "rollout/ep_rew_mean": 863.6390380859375,
#     "time/fps": 75,
#     "time/iterations": 202,
#     "time/time_elapsed": 601,
#     "train/entropy": 0.30405375361442566,
#     "train/entropy_loss": -0.000304053770378232,
#     "train/grad_norm": 2.705763816833496,
#     "train/loss": 0.7639878988265991,
#     "train/n_updates": 201,
#     "train/policy_gradient_loss": 0.7642919421195984
# }
# {
#     "global_step": 46115,
#     "num_episodes": 208,
#     "rollout/ep_len_mean": 170.3,
#     "rollout/ep_rew_mean": 975.2060546875,
#     "time/fps": 75,
#     "time/iterations": 208,
#     "time/time_elapsed": 614,
#     "train/entropy": 0.2875129282474518,
#     "train/entropy_loss": -0.0002875129284802824,
#     "train/grad_norm": 0.5043315887451172,
#     "train/loss": 0.5885589718818665,
#     "train/n_updates": 207,
#     "train/policy_gradient_loss": 0.5888465046882629
# }
# {
#     "global_step": 47070,
#     "num_episodes": 214,
#     "rollout/ep_len_mean": 161.5,
#     "rollout/ep_rew_mean": 958.2927856445312,
#     "time/fps": 75,
#     "time/iterations": 214,
#     "time/time_elapsed": 627,
#     "train/entropy": 0.27803996205329895,
#     "train/entropy_loss": -0.0002780399809125811,
#     "train/grad_norm": 1.759509801864624,
#     "train/loss": 0.6657686233520508,
#     "train/n_updates": 213,
#     "train/policy_gradient_loss": 0.666046679019928
# }
# {
#     "global_step": 48117,
#     "num_episodes": 219,
#     "rollout/ep_len_mean": 182.6,
#     "rollout/ep_rew_mean": 664.0953369140625,
#     "time/fps": 75,
#     "time/iterations": 219,
#     "time/time_elapsed": 641,
#     "train/entropy": 0.6498301029205322,
#     "train/entropy_loss": -0.0006498301518149674,
#     "train/grad_norm": 0.10313694179058075,
#     "train/loss": -0.44828835129737854,
#     "train/n_updates": 218,
#     "train/policy_gradient_loss": -0.44763851165771484
# }
# {
#     "global_step": 49128,
#     "num_episodes": 225,
#     "rollout/ep_len_mean": 190.5,
#     "rollout/ep_rew_mean": 407.49322509765625,
#     "time/fps": 74,
#     "time/iterations": 225,
#     "time/time_elapsed": 655,
#     "train/entropy": 0.5176494121551514,
#     "train/entropy_loss": -0.0005176494596526027,
#     "train/grad_norm": 0.5227974653244019,
#     "train/loss": 0.9143558144569397,
#     "train/n_updates": 224,
#     "train/policy_gradient_loss": 0.914873480796814
# }
# {
#     "global_step": 50002,
#     "num_episodes": 231,
#     "rollout/ep_len_mean": 147.8,
#     "rollout/ep_rew_mean": 604.0339965820312,
#     "time/fps": 75,
#     "time/iterations": 231,
#     "time/time_elapsed": 665,
#     "train/entropy": 0.46778374910354614,
#     "train/entropy_loss": -0.00046778377145528793,
#     "train/grad_norm": 3.1709797382354736,
#     "train/loss": 0.7026296257972717,
#     "train/n_updates": 230,
#     "train/policy_gradient_loss": 0.703097403049469
# }
# Задача не решена за 50000 шагов

# %% [markdown]
# # 2 REINFORCE с базовым уровнем
# Градиент стратагии зависит от величины отдачи. Однако отдача может быть очень шумной оценкой $Q ^ {\pi} (s, a)$, особенно в средах с отложенными или редкими вознаграждениями. Этот шум приводит к высокой дисперсии в оценках градиента, что влечёт за собой сильные изменения стратегии. При этом обучение становится нестабильным, а сходимость медленной. Одним из способов снижения дисперсии является использование базового уровня $b(s)$. Базовый уровень $b(s)$ не зависит от действий, поэтому вычитание из оценки $Q ^ {\pi} (s, a)$ не приводит к смещению оценки градиента.
#
# $$\nabla_\theta J(\theta) = \mathbb{E}_\pi [(G_t - b(s)) \nabla_\theta \ln \pi_\theta(a_t \vert s_t)]$$
#
# ## 2.1 REINFORCE с необучаемым базовым уровнем (средняя отдача)
# В некоторых случаях в качестве базового уровня достаточно использовать среднюю отдачу за предыдущие эпизоды. Даже такая простая эвристика может помочь стабилизировать процесс обучения на ранних этапах.

# %% [markdown]
# (3 балла)

# %%
# AverageReturnBuffer хранит статистику - среднюю отдачу по всем состояниям и эпизодам за время обучения
class AverageReturnBuffer(Buffer):
    def __init__(self, gamma: float = 0.99, device: Union[torch.device, str] = "cpu"):
        # Дополнительные переменные, необходимые для вычисления средней отдачи
        super().__init__(gamma, device)
        self.accum_ret = 0
        self.accum_cnt = 0

    def get_average_return(self):
        return self.accum_ret / self.accum_cnt

    def compute_returns(self) -> None:
        super().compute_returns()

        self.accum_ret += sum(self.returns)
        self.accum_cnt += len(self.returns)

# %% [markdown]
# (1 балл)

# %%
class AverageReturnBaselineReinforce(Reinforce):
    def __init__(self, env: gym.Env, learning_rate: float = 2.5e-4, gamma: float = 0.99, ent_coef: float = 0.001,
                 max_grad_norm: float = 0.5, stats_window_size: int = 10, policy_class: Type[ReinforcePolicy] = ReinforcePolicy,
                 policy_kwargs: Optional[Dict[str, Any]] = None, buffer_class: Type[AverageReturnBuffer] = AverageReturnBuffer,
                 buffer_kwargs: Optional[Dict[str, Any]] = None, seed: Optional[int] = None,
                 device: Union[torch.device, str] = "cuda"):
        super().__init__(env, learning_rate, gamma, ent_coef, max_grad_norm, stats_window_size, policy_class, policy_kwargs,
                         buffer_class, buffer_kwargs, seed, device)

    def train(self) -> None:
        self.policy.set_training_mode(True)

        rollout_data = self.buffer.get()
        actions = rollout_data.actions.long()
        policy_output = self.policy.evaluate_actions(rollout_data.observations, actions)
        log_prob = policy_output['log_prob']
        entropy = policy_output['entropy']

        # Получаем среднюю отдачу
        baseline = self.buffer.get_average_return()

        # Посчитать отдачи с учётом базового уровня
        returns = rollout_data.returns - baseline

        # Policy gradient loss
        policy_loss = -(returns * log_prob).mean()

        # Entropy loss
        entropy = torch.mean(entropy)
        entropy_loss = -self.ent_coef * entropy

        loss = policy_loss + entropy_loss

        # Optimization step
        self.policy.optimizer.zero_grad()
        loss.backward()
        grad_norm = torch.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
        self.policy.optimizer.step()

        self._n_updates += 1

        self.log_dict = dict([
            ("train/entropy_loss", entropy_loss.item()), ("train/entropy", entropy.item()),
            ("train/policy_gradient_loss", policy_loss.item()), ("train/loss", loss.item()),
            ("train/grad_norm", grad_norm.item()), ("train/n_updates", self._n_updates),
            ("train/baseline", baseline)
        ])

# %%
run_algorithm(
    algorithm_class=AverageReturnBaselineReinforce,
    algorithm_kwargs=dict(seed=0, ),
    use_wandb=WANDB_IS_AVAILABLE,
    wandb_kwargs=dict(project='seminar_actor-critic', monitor_gym=True, name='reinforce_simple-baseline'),
    learn_kwargs=dict(max_timesteps=50000, log_interval=1000, expected_return=2000, save_checkpoint_interval=1000,
                    save_checkpoint_path='/content/drive/My Drive/seminar_actor-critic/reinforce_simple-baseline')
)
# Out:
# c:\Users\iRU\AppData\Local\Programs\Python\Python312\Lib\site-packages\vizdoom\gymnasium_wrapper\base_gymnasium_env.py:84: UserWarning: Detected screen format CRCGCB. Only RGB24 and GRAY8 are supported in the Gymnasium wrapper. Forcing RGB24.
#   warnings.warn(
# Using cuda device
# C:\Users\iRU\AppData\Local\Temp\ipykernel_12336\3336005168.py:79: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   self._last_obs = np.array(self._last_obs)
# C:\Users\iRU\AppData\Local\Temp\ipykernel_12336\3336005168.py:100: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   self._last_obs = np.array(new_obs)
# {
#     "global_step": 1375,
#     "num_episodes": 3,
#     "rollout/ep_len_mean": 458.3333333333333,
#     "rollout/ep_rew_mean": -47.959659576416016,
#     "time/fps": 70,
#     "time/iterations": 3,
#     "time/time_elapsed": 19,
#     "train/baseline": -0.15949776794469192,
#     "train/entropy": 2.0790271759033203,
#     "train/entropy_loss": -0.0020790272392332554,
#     "train/grad_norm": 0.019206242635846138,
#     "train/loss": 0.17236290872097015,
#     "train/n_updates": 2,
#     "train/policy_gradient_loss": 0.17444193363189697
# }
# {
#     "global_step": 2233,
#     "num_episodes": 5,
#     "rollout/ep_len_mean": 446.6,
#     "rollout/ep_rew_mean": -43.63574981689453,
#     "time/fps": 69,
#     "time/iterations": 5,
#     "time/time_elapsed": 32,
#     "train/baseline": -0.10097277974031772,
#     "train/entropy": 2.078903913497925,
#     "train/entropy_loss": -0.0020789040718227625,
#     "train/grad_norm": 0.01922071911394596,
#     "train/loss": 0.023100731894373894,
#     "train/n_updates": 4,
#     "train/policy_gradient_loss": 0.025179635733366013
# }
# {
#     "global_step": 3420,
#     "num_episodes": 6,
#     "rollout/ep_len_mean": 570.0,
#     "rollout/ep_rew_mean": -39.560428619384766,
#     "time/fps": 70,
#     "time/iterations": 6,
#     "time/time_elapsed": 48,
#     "train/baseline": -0.0962862069398752,
#     "train/entropy": 2.0781943798065186,
#     "train/entropy_loss": -0.0020781944040209055,
#     "train/grad_norm": 0.0195792093873024,
#     "train/loss": 0.04002673551440239,
#     "train/n_updates": 5,
#     "train/policy_gradient_loss": 0.04210492968559265
# }
# {
#     "global_step": 4161,
#     "num_episodes": 7,
#     "rollout/ep_len_mean": 594.4285714285714,
#     "rollout/ep_rew_mean": -23.075815200805664,
#     "time/fps": 70,
#     "time/iterations": 7,
#     "time/time_elapsed": 59,
#     "train/baseline": -0.06720623534516994,
#     "train/entropy": 2.075376272201538,
#     "train/entropy_loss": -0.0020753764547407627,
#     "train/grad_norm": 0.01185547560453415,
#     "train/loss": 0.11210662126541138,
#     "train/n_updates": 6,
#     "train/policy_gradient_loss": 0.1141819953918457
# }
# {
#     "global_step": 5010,
#     "num_episodes": 10,
#     "rollout/ep_len_mean": 501.0,
#     "rollout/ep_rew_mean": -34.9827995300293,
#     "time/fps": 70,
#     "time/iterations": 10,
#     "time/time_elapsed": 70,
#     "train/baseline": -0.0532773507036253,
#     "train/entropy": 2.039483070373535,
#     "train/entropy_loss": -0.002039483282715082,
#     "train/grad_norm": 0.07179135829210281,
#     "train/loss": 0.02822522073984146,
#     "train/n_updates": 9,
#     "train/policy_gradient_loss": 0.030264703556895256
# }
# {
#     "global_step": 6174,
#     "num_episodes": 14,
#     "rollout/ep_len_mean": 435.2,
#     "rollout/ep_rew_mean": 4.503027439117432,
#     "time/fps": 71,
#     "time/iterations": 14,
#     "time/time_elapsed": 86,
#     "train/baseline": -0.03683136947287948,
#     "train/entropy": 1.8475475311279297,
#     "train/entropy_loss": -0.0018475475953891873,
#     "train/grad_norm": 0.26125168800354004,
#     "train/loss": 0.9351333975791931,
#     "train/n_updates": 13,
#     "train/policy_gradient_loss": 0.9369809627532959
# }
# {
#     "global_step": 7337,
#     "num_episodes": 18,
#     "rollout/ep_len_mean": 294.7,
#     "rollout/ep_rew_mean": 36.03020477294922,
#     "time/fps": 72,
#     "time/iterations": 18,
#     "time/time_elapsed": 101,
#     "train/baseline": -0.05061605611599067,
#     "train/entropy": 0.5054213404655457,
#     "train/entropy_loss": -0.0005054213688708842,
#     "train/grad_norm": 0.09791415184736252,
#     "train/loss": -0.14763590693473816,
#     "train/n_updates": 17,
#     "train/policy_gradient_loss": -0.14713048934936523
# }
# {
#     "global_step": 8475,
#     "num_episodes": 20,
#     "rollout/ep_len_mean": 346.5,
#     "rollout/ep_rew_mean": 115.14216613769531,
#     "time/fps": 72,
#     "time/iterations": 20,
#     "time/time_elapsed": 116,
#     "train/baseline": -0.03358050118136404,
#     "train/entropy": 0.7484816312789917,
#     "train/entropy_loss": -0.0007484816596843302,
#     "train/grad_norm": 0.1712673157453537,
#     "train/loss": 0.32798922061920166,
#     "train/n_updates": 19,
#     "train/policy_gradient_loss": 0.32873770594596863
# }
# {
#     "global_step": 9155,
#     "num_episodes": 24,
#     "rollout/ep_len_mean": 298.1,
#     "rollout/ep_rew_mean": 731.4612426757812,
#     "time/fps": 73,
#     "time/iterations": 24,
#     "time/time_elapsed": 125,
#     "train/baseline": 0.2761193765070703,
#     "train/entropy": 0.3051384389400482,
#     "train/entropy_loss": -0.000305138441035524,
#     "train/grad_norm": 9.130877494812012,
#     "train/loss": 1.8689260482788086,
#     "train/n_updates": 23,
#     "train/policy_gradient_loss": 1.8692312240600586
# }
# {
#     "global_step": 10003,
#     "num_episodes": 29,
#     "rollout/ep_len_mean": 211.3,
#     "rollout/ep_rew_mean": 1811.5218505859375,
#     "time/fps": 73,
#     "time/iterations": 29,
#     "time/time_elapsed": 136,
#     "train/baseline": 1.0358538283300727,
#     "train/entropy": 0.0003431753139011562,
#     "train/entropy_loss": -3.43175344141855e-07,
#     "train/grad_norm": 0.020750515162944794,
#     "train/loss": 0.00024180627951864153,
#     "train/n_updates": 28,
#     "train/policy_gradient_loss": 0.0002421494573354721
# }
# Решено!

# %% [markdown]
# ## 2.2 REINFORCE с обучаемым базовым уровнем
# Чаще всего в качестве базового уровня применяется оценка функции полезности состояний $b(s) = v(s) = \mathbb{E}[G_t| s_t = s]$, получаемая с помощью нейросетевой аппроксимации. При этом величину $G_t - b(s_t)$ можно рассматривать как оценку функции преимущества (advantage) действия $a_t$ в состоянии $s_t$: $A(s_t, a_t) = Q(s_t, a_t) - V(s_t)$.
#
# #### Shared-encoder
# Модели стратегии и функции полезности могут обучаться в разных режимах — стратегия только on-policy (шаг обучения на текущей собранной подтраектории), а полезность on-policy или off-policy (шаг обучения на текущей подтраектории или на батче из replay buffer). Это с одной стороны привносит гибкость в обучение, с другой — усложняет его.
#
# Если обе модели обучаются on-policy, то имеет смысл объединить их сетки в одну и делать общий шаг обратного распространения ошибки. Однако, если они обучаются в разных режимах (и с разной частотой обновления), то велика вероятность, что их шаги обучения могут начать конфликтовать в случае общего тела — для такого варианта намного предпочтительнее разделить их на разные подсети (либо аккуратно настраивать гиперпарметры, чтобы стабилизировать обучение). В целом, рекомендуется использовать общий энкодер наблюдений, а далее как можно скорее разделять головы.

# %% [markdown]
# (2 балла)

# %%
class ValuePolicy(ReinforcePolicy):
    def __init__(self, observation_space: gym.Space, action_space: gym.Space, lr: float,
                 optimizer_class: Type[torch.optim.Optimizer] = torch.optim.RMSprop,
                 optimizer_kwargs: Dict[str, Any] = {'eps': 1e-5}):
        # Добавить слой для вычисления полезности состояний
        super().__init__(observation_space, action_space, lr, optimizer_class, optimizer_kwargs)

        self.value_net = torch.nn.Linear(self.features_extractor.features_dim, 1)

    def evaluate_actions(self, obs: torch.Tensor, actions_taken: torch.Tensor) -> Dict[str, torch.Tensor]:
        # Метод должен возвращать словарь с 'features', 'log_prob', 'entropy' и 'values' - полезность obs
        data = super().evaluate_actions(obs, actions_taken)
        data['value'] = self.value_net(data['features']).squeeze(-1)
        return data

# %% [markdown]
# (1 балл)

# %%
class ValueBaselineReinforce(Reinforce):
    def __init__(self, env: gym.Env, learning_rate: float = 2.5e-4, gamma: float = 0.99, ent_coef: float = 0.001,
                 max_grad_norm: float = 0.5, stats_window_size: int = 10, policy_class: Type[ValuePolicy] = ValuePolicy,
                 policy_kwargs: Optional[Dict[str, Any]] = None, buffer_class: Type[Buffer] = Buffer,
                 buffer_kwargs: Optional[Dict[str, Any]] = None, seed: Optional[int] = None,
                 device: Union[torch.device, str] = "cuda", vf_coef: float = 0.5,):
        super().__init__(env, learning_rate, gamma, ent_coef, max_grad_norm, stats_window_size, policy_class,
                         policy_kwargs, buffer_class, buffer_kwargs, seed, device)
        self.vf_coef = vf_coef

    def train(self) -> None:
        self.policy.set_training_mode(True)

        rollout_data = self.buffer.get()
        actions = rollout_data.actions.long()
        policy_output = self.policy.evaluate_actions(rollout_data.observations, actions)
        log_prob = policy_output['log_prob']
        entropy = policy_output['entropy']
        values = policy_output['value']
        advantages = rollout_data.returns - values.detach()
        baseline = values.mean().item()

        # Policy gradient loss
        policy_loss = -(advantages * log_prob).mean()

        # Entropy loss
        entropy = torch.mean(entropy)
        entropy_loss = -self.ent_coef * entropy

        # Value loss с коэффициентов self.vf_coef
        value_loss = self.vf_coef * F.mse_loss(values, rollout_data.returns)

        loss = policy_loss + entropy_loss + value_loss

        # Optimization step
        self.policy.optimizer.zero_grad()
        loss.backward()
        grad_norm = torch.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
        self.policy.optimizer.step()

        self._n_updates += 1

        self.log_dict = dict([
            ("train/entropy_loss", entropy_loss.item()), ("train/entropy", entropy.item()),
            ("train/policy_gradient_loss", policy_loss.item()), ("train/loss", loss.item()),
            ("train/grad_norm", grad_norm.item()), ("train/n_updates", self._n_updates),
            ("train/baseline", baseline), ("train/value_loss", value_loss.item())
        ])

# %%
run_algorithm(
    algorithm_class=ValueBaselineReinforce,
    algorithm_kwargs=dict(seed=0, ),
    use_wandb=WANDB_IS_AVAILABLE,
    wandb_kwargs=dict(project='seminar_actor-critic', monitor_gym=True, name='reinforce_value-baseline'),
    learn_kwargs=dict(max_timesteps=50000, log_interval=1000, expected_return=2000, save_checkpoint_interval=1000,
                    save_checkpoint_path='/content/drive/My Drive/seminar_actor-critic/reinforce_value-baseline')
)
# Out:
# Using cuda device
# C:\Users\iRU\AppData\Local\Temp\ipykernel_12336\3336005168.py:79: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   self._last_obs = np.array(self._last_obs)
# C:\Users\iRU\AppData\Local\Temp\ipykernel_12336\3336005168.py:100: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   self._last_obs = np.array(new_obs)
# {
#     "global_step": 1375,
#     "num_episodes": 3,
#     "rollout/ep_len_mean": 458.3333333333333,
#     "rollout/ep_rew_mean": -45.55570602416992,
#     "time/fps": 71,
#     "time/iterations": 3,
#     "time/time_elapsed": 19,
#     "train/baseline": -0.24722054600715637,
#     "train/entropy": 2.078947067260742,
#     "train/entropy_loss": -0.0020789471454918385,
#     "train/grad_norm": 0.3997473418712616,
#     "train/loss": 0.47978663444519043,
#     "train/n_updates": 2,
#     "train/policy_gradient_loss": 0.40324410796165466,
#     "train/value_loss": 0.07862146943807602
# }
# {
#     "global_step": 2184,
#     "num_episodes": 5,
#     "rollout/ep_len_mean": 436.8,
#     "rollout/ep_rew_mean": -53.27062225341797,
#     "time/fps": 70,
#     "time/iterations": 5,
#     "time/time_elapsed": 31,
#     "train/baseline": -0.02421853132545948,
#     "train/entropy": 2.079296112060547,
#     "train/entropy_loss": -0.0020792961586266756,
#     "train/grad_norm": 0.2107727974653244,
#     "train/loss": -0.19974948465824127,
#     "train/n_updates": 4,
#     "train/policy_gradient_loss": -0.25566741824150085,
#     "train/value_loss": 0.05799724534153938
# }
# {
#     "global_step": 3181,
#     "num_episodes": 6,
#     "rollout/ep_len_mean": 530.1666666666666,
#     "rollout/ep_rew_mean": -56.4785270690918,
#     "time/fps": 70,
#     "time/iterations": 6,
#     "time/time_elapsed": 45,
#     "train/baseline": -0.07925891876220703,
#     "train/entropy": 2.079193592071533,
#     "train/entropy_loss": -0.002079193713143468,
#     "train/grad_norm": 0.2725958228111267,
#     "train/loss": -0.13205879926681519,
#     "train/n_updates": 5,
#     "train/policy_gradient_loss": -0.1821046620607376,
#     "train/value_loss": 0.05212504789233208
# }
# {
#     "global_step": 4240,
#     "num_episodes": 9,
#     "rollout/ep_len_mean": 471.1111111111111,
#     "rollout/ep_rew_mean": -62.16339111328125,
#     "time/fps": 71,
#     "time/iterations": 9,
#     "time/time_elapsed": 59,
#     "train/baseline": -0.07630308717489243,
#     "train/entropy": 2.079177141189575,
#     "train/entropy_loss": -0.0020791771821677685,
#     "train/grad_norm": 0.37070512771606445,
#     "train/loss": -0.1827780157327652,
#     "train/n_updates": 8,
#     "train/policy_gradient_loss": -0.2653299570083618,
#     "train/value_loss": 0.08463113009929657
# }
# {
#     "global_step": 5041,
#     "num_episodes": 11,
#     "rollout/ep_len_mean": 462.9,
#     "rollout/ep_rew_mean": -61.05461502075195,
#     "time/fps": 72,
#     "time/iterations": 11,
#     "time/time_elapsed": 69,
#     "train/baseline": -0.19604986906051636,
#     "train/entropy": 2.078810930252075,
#     "train/entropy_loss": -0.002078810939565301,
#     "train/grad_norm": 0.4473893940448761,
#     "train/loss": 0.11230327188968658,
#     "train/n_updates": 10,
#     "train/policy_gradient_loss": 0.07808804512023926,
#     "train/value_loss": 0.036294031888246536
# }
# {
#     "global_step": 6447,
#     "num_episodes": 13,
#     "rollout/ep_len_mean": 507.2,
#     "rollout/ep_rew_mean": -62.01993942260742,
#     "time/fps": 72,
#     "time/iterations": 13,
#     "time/time_elapsed": 88,
#     "train/baseline": -0.21976546943187714,
#     "train/entropy": 2.0791423320770264,
#     "train/entropy_loss": -0.002079142490401864,
#     "train/grad_norm": 0.4559670388698578,
#     "train/loss": 0.12356653809547424,
#     "train/n_updates": 12,
#     "train/policy_gradient_loss": 0.08340346068143845,
#     "train/value_loss": 0.04224221780896187
# }
# {
#     "global_step": 7890,
#     "num_episodes": 15,
#     "rollout/ep_len_mean": 570.6,
#     "rollout/ep_rew_mean": -63.839698791503906,
#     "time/fps": 72,
#     "time/iterations": 15,
#     "time/time_elapsed": 108,
#     "train/baseline": -0.07238921523094177,
#     "train/entropy": 2.079256534576416,
#     "train/entropy_loss": -0.0020792565774172544,
#     "train/grad_norm": 0.3211647868156433,
#     "train/loss": -0.11413323879241943,
#     "train/n_updates": 14,
#     "train/policy_gradient_loss": -0.15793853998184204,
#     "train/value_loss": 0.04588456451892853
# }
# {
#     "global_step": 8341,
#     "num_episodes": 16,
#     "rollout/ep_len_mean": 516.0,
#     "rollout/ep_rew_mean": -65.46333312988281,
#     "time/fps": 72,
#     "time/iterations": 16,
#     "time/time_elapsed": 114,
#     "train/baseline": -0.08712095022201538,
#     "train/entropy": 2.0792462825775146,
#     "train/entropy_loss": -0.0020792463328689337,
#     "train/grad_norm": 0.31591272354125977,
#     "train/loss": 0.07491979002952576,
#     "train/n_updates": 15,
#     "train/policy_gradient_loss": 0.004254499915987253,
#     "train/value_loss": 0.07274453341960907
# }
# {
#     "global_step": 9402,
#     "num_episodes": 19,
#     "rollout/ep_len_mean": 516.2,
#     "rollout/ep_rew_mean": -75.47727966308594,
#     "time/fps": 72,
#     "time/iterations": 19,
#     "time/time_elapsed": 129,
#     "train/baseline": -0.15622395277023315,
#     "train/entropy": 2.079063653945923,
#     "train/entropy_loss": -0.002079063793644309,
#     "train/grad_norm": 0.633569598197937,
#     "train/loss": -0.2484004646539688,
#     "train/n_updates": 18,
#     "train/policy_gradient_loss": -0.29797932505607605,
#     "train/value_loss": 0.05165793001651764
# }
# {
#     "global_step": 10241,
#     "num_episodes": 21,
#     "rollout/ep_len_mean": 520.0,
#     "rollout/ep_rew_mean": -73.05726623535156,
#     "time/fps": 72,
#     "time/iterations": 21,
#     "time/time_elapsed": 141,
#     "train/baseline": -0.23996731638908386,
#     "train/entropy": 2.0783164501190186,
#     "train/entropy_loss": -0.0020783166401088238,
#     "train/grad_norm": 0.42584627866744995,
#     "train/loss": 0.330867737531662,
#     "train/n_updates": 20,
#     "train/policy_gradient_loss": 0.29936355352401733,
#     "train/value_loss": 0.03358251973986626
# }
# {
#     "global_step": 11236,
#     "num_episodes": 22,
#     "rollout/ep_len_mean": 561.5,
#     "rollout/ep_rew_mean": -60.68071746826172,
#     "time/fps": 72,
#     "time/iterations": 22,
#     "time/time_elapsed": 154,
#     "train/baseline": -0.16311657428741455,
#     "train/entropy": 2.078930377960205,
#     "train/entropy_loss": -0.0020789303816854954,
#     "train/grad_norm": 0.49191609025001526,
#     "train/loss": -0.2086719125509262,
#     "train/n_updates": 21,
#     "train/policy_gradient_loss": -0.25790658593177795,
#     "train/value_loss": 0.05131359025835991
# }
# {
#     "global_step": 12640,
#     "num_episodes": 25,
#     "rollout/ep_len_mean": 475.0,
#     "rollout/ep_rew_mean": -69.2500228881836,
#     "time/fps": 72,
#     "time/iterations": 25,
#     "time/time_elapsed": 174,
#     "train/baseline": -0.15575720369815826,
#     "train/entropy": 2.0785443782806396,
#     "train/entropy_loss": -0.002078544581308961,
#     "train/grad_norm": 0.4883541166782379,
#     "train/loss": -0.20371462404727936,
#     "train/n_updates": 24,
#     "train/policy_gradient_loss": -0.2532162368297577,
#     "train/value_loss": 0.05158014968037605
# }
# {
#     "global_step": 13155,
#     "num_episodes": 27,
#     "rollout/ep_len_mean": 456.1,
#     "rollout/ep_rew_mean": -50.61029052734375,
#     "time/fps": 72,
#     "time/iterations": 27,
#     "time/time_elapsed": 181,
#     "train/baseline": -0.128556489944458,
#     "train/entropy": 2.0785210132598877,
#     "train/entropy_loss": -0.002078521065413952,
#     "train/grad_norm": 0.4187585115432739,
#     "train/loss": -0.19475656747817993,
#     "train/n_updates": 26,
#     "train/policy_gradient_loss": -0.29686352610588074,
#     "train/value_loss": 0.10418548434972763
# }
# {
#     "global_step": 14204,
#     "num_episodes": 31,
#     "rollout/ep_len_mean": 396.3,
#     "rollout/ep_rew_mean": -50.06451416015625,
#     "time/fps": 72,
#     "time/iterations": 31,
#     "time/time_elapsed": 195,
#     "train/baseline": -0.230460062623024,
#     "train/entropy": 2.076245069503784,
#     "train/entropy_loss": -0.0020762451458722353,
#     "train/grad_norm": 0.465995192527771,
#     "train/loss": -0.0010527130216360092,
#     "train/n_updates": 30,
#     "train/policy_gradient_loss": -0.027969740331172943,
#     "train/value_loss": 0.0289932731539011
# }
# {
#     "global_step": 15170,
#     "num_episodes": 34,
#     "rollout/ep_len_mean": 322.9,
#     "rollout/ep_rew_mean": -35.37691879272461,
#     "time/fps": 72,
#     "time/iterations": 34,
#     "time/time_elapsed": 208,
#     "train/baseline": -0.27489256858825684,
#     "train/entropy": 2.072293519973755,
#     "train/entropy_loss": -0.002072293544188142,
#     "train/grad_norm": 0.4244536757469177,
#     "train/loss": 0.46602901816368103,
#     "train/n_updates": 33,
#     "train/policy_gradient_loss": 0.4054466485977173,
#     "train/value_loss": 0.06265468150377274
# }
# {
#     "global_step": 16018,
#     "num_episodes": 36,
#     "rollout/ep_len_mean": 313.4,
#     "rollout/ep_rew_mean": -48.8425178527832,
#     "time/fps": 72,
#     "time/iterations": 36,
#     "time/time_elapsed": 219,
#     "train/baseline": -0.15118812024593353,
#     "train/entropy": 2.0757625102996826,
#     "train/entropy_loss": -0.0020757627207785845,
#     "train/grad_norm": 0.22309865057468414,
#     "train/loss": -0.011516988277435303,
#     "train/n_updates": 35,
#     "train/policy_gradient_loss": -0.04350578039884567,
#     "train/value_loss": 0.034064553678035736
# }
# {
#     "global_step": 17236,
#     "num_episodes": 39,
#     "rollout/ep_len_mean": 361.4,
#     "rollout/ep_rew_mean": -25.294185638427734,
#     "time/fps": 72,
#     "time/iterations": 39,
#     "time/time_elapsed": 236,
#     "train/baseline": -0.19955137372016907,
#     "train/entropy": 2.072413682937622,
#     "train/entropy_loss": -0.0020724136848002672,
#     "train/grad_norm": 0.7368507981300354,
#     "train/loss": 0.8856428861618042,
#     "train/n_updates": 38,
#     "train/policy_gradient_loss": 0.7800670862197876,
#     "train/value_loss": 0.10764821618795395
# }
# {
#     "global_step": 18073,
#     "num_episodes": 42,
#     "rollout/ep_len_mean": 355.0,
#     "rollout/ep_rew_mean": -15.415964126586914,
#     "time/fps": 72,
#     "time/iterations": 42,
#     "time/time_elapsed": 248,
#     "train/baseline": -0.16625232994556427,
#     "train/entropy": 2.074037790298462,
#     "train/entropy_loss": -0.0020740379113703966,
#     "train/grad_norm": 0.17208659648895264,
#     "train/loss": -0.0803709402680397,
#     "train/n_updates": 41,
#     "train/policy_gradient_loss": -0.10168131440877914,
#     "train/value_loss": 0.02338441275060177
# }
# {
#     "global_step": 19097,
#     "num_episodes": 46,
#     "rollout/ep_len_mean": 307.9,
#     "rollout/ep_rew_mean": -26.10577392578125,
#     "time/fps": 72,
#     "time/iterations": 46,
#     "time/time_elapsed": 263,
#     "train/baseline": -0.17470094561576843,
#     "train/entropy": 2.07258677482605,
#     "train/entropy_loss": -0.0020725869107991457,
#     "train/grad_norm": 0.3625558018684387,
#     "train/loss": -0.3588760197162628,
#     "train/n_updates": 45,
#     "train/policy_gradient_loss": -0.4110291600227356,
#     "train/value_loss": 0.054225701838731766
# }
# {
#     "global_step": 20322,
#     "num_episodes": 49,
#     "rollout/ep_len_mean": 308.6,
#     "rollout/ep_rew_mean": -56.408592224121094,
#     "time/fps": 72,
#     "time/iterations": 49,
#     "time/time_elapsed": 279,
#     "train/baseline": -0.2164260894060135,
#     "train/entropy": 2.0686490535736084,
#     "train/entropy_loss": -0.002068649046123028,
#     "train/grad_norm": 0.1873796135187149,
#     "train/loss": 0.11107076704502106,
#     "train/n_updates": 48,
#     "train/policy_gradient_loss": 0.09412515163421631,
#     "train/value_loss": 0.0190142635256052
# }
# {
#     "global_step": 21056,
#     "num_episodes": 51,
#     "rollout/ep_len_mean": 320.3,
#     "rollout/ep_rew_mean": -38.31365966796875,
#     "time/fps": 72,
#     "time/iterations": 51,
#     "time/time_elapsed": 289,
#     "train/baseline": -0.2118321806192398,
#     "train/entropy": 2.0687148571014404,
#     "train/entropy_loss": -0.002068714937195182,
#     "train/grad_norm": 0.7628163695335388,
#     "train/loss": 0.9759883880615234,
#     "train/n_updates": 50,
#     "train/policy_gradient_loss": 0.8065955638885498,
#     "train/value_loss": 0.1714615523815155
# }
# {
#     "global_step": 22301,
#     "num_episodes": 55,
#     "rollout/ep_len_mean": 345.7,
#     "rollout/ep_rew_mean": -33.641815185546875,
#     "time/fps": 72,
#     "time/iterations": 55,
#     "time/time_elapsed": 307,
#     "train/baseline": -0.1502608358860016,
#     "train/entropy": 2.072355031967163,
#     "train/entropy_loss": -0.00207235524430871,
#     "train/grad_norm": 0.3320938050746918,
#     "train/loss": -0.050300538539886475,
#     "train/n_updates": 54,
#     "train/policy_gradient_loss": -0.08977976441383362,
#     "train/value_loss": 0.041551582515239716
# }
# {
#     "global_step": 23143,
#     "num_episodes": 58,
#     "rollout/ep_len_mean": 321.2,
#     "rollout/ep_rew_mean": -27.529338836669922,
#     "time/fps": 72,
#     "time/iterations": 58,
#     "time/time_elapsed": 318,
#     "train/baseline": -0.15914149582386017,
#     "train/entropy": 2.071890354156494,
#     "train/entropy_loss": -0.002071890514343977,
#     "train/grad_norm": 0.27127447724342346,
#     "train/loss": -0.033847250044345856,
#     "train/n_updates": 57,
#     "train/policy_gradient_loss": -0.10960685461759567,
#     "train/value_loss": 0.07783149182796478
# }
# {
#     "global_step": 24219,
#     "num_episodes": 61,
#     "rollout/ep_len_mean": 316.3,
#     "rollout/ep_rew_mean": -13.601977348327637,
#     "time/fps": 72,
#     "time/iterations": 61,
#     "time/time_elapsed": 334,
#     "train/baseline": -0.19864186644554138,
#     "train/entropy": 2.0667483806610107,
#     "train/entropy_loss": -0.0020667484495788813,
#     "train/grad_norm": 0.33669668436050415,
#     "train/loss": 0.29807955026626587,
#     "train/n_updates": 60,
#     "train/policy_gradient_loss": 0.2429201304912567,
#     "train/value_loss": 0.05722616985440254
# }
# {
#     "global_step": 25531,
#     "num_episodes": 64,
#     "rollout/ep_len_mean": 361.2,
#     "rollout/ep_rew_mean": 14.01037311553955,
#     "time/fps": 72,
#     "time/iterations": 64,
#     "time/time_elapsed": 351,
#     "train/baseline": -0.1643035113811493,
#     "train/entropy": 2.068105697631836,
#     "train/entropy_loss": -0.0020681058522313833,
#     "train/grad_norm": 0.28924158215522766,
#     "train/loss": 0.10205455124378204,
#     "train/n_updates": 63,
#     "train/policy_gradient_loss": 0.05166352540254593,
#     "train/value_loss": 0.05245913565158844
# }
# {
#     "global_step": 26170,
#     "num_episodes": 67,
#     "rollout/ep_len_mean": 327.5,
#     "rollout/ep_rew_mean": 3.651345729827881,
#     "time/fps": 72,
#     "time/iterations": 67,
#     "time/time_elapsed": 361,
#     "train/baseline": -0.1797153651714325,
#     "train/entropy": 2.06655216217041,
#     "train/entropy_loss": -0.002066552173346281,
#     "train/grad_norm": 0.1603996753692627,
#     "train/loss": 0.020665831863880157,
#     "train/n_updates": 66,
#     "train/policy_gradient_loss": -0.042316265404224396,
#     "train/value_loss": 0.06504864990711212
# }
# {
#     "global_step": 27049,
#     "num_episodes": 71,
#     "rollout/ep_len_mean": 283.0,
#     "rollout/ep_rew_mean": -16.939992904663086,
#     "time/fps": 72,
#     "time/iterations": 71,
#     "time/time_elapsed": 375,
#     "train/baseline": -0.299829363822937,
#     "train/entropy": 2.04030442237854,
#     "train/entropy_loss": -0.0020403044763952494,
#     "train/grad_norm": 0.40319666266441345,
#     "train/loss": 0.08906180411577225,
#     "train/n_updates": 70,
#     "train/policy_gradient_loss": 0.05534370243549347,
#     "train/value_loss": 0.035758405923843384
# }
# {
#     "global_step": 28014,
#     "num_episodes": 75,
#     "rollout/ep_len_mean": 230.5,
#     "rollout/ep_rew_mean": -21.213897705078125,
#     "time/fps": 71,
#     "time/iterations": 75,
#     "time/time_elapsed": 390,
#     "train/baseline": -0.2041982263326645,
#     "train/entropy": 2.051508903503418,
#     "train/entropy_loss": -0.0020515089854598045,
#     "train/grad_norm": 0.5510314702987671,
#     "train/loss": 0.4304933547973633,
#     "train/n_updates": 74,
#     "train/policy_gradient_loss": 0.34671643376350403,
#     "train/value_loss": 0.08582841604948044
# }
# {
#     "global_step": 29199,
#     "num_episodes": 79,
#     "rollout/ep_len_mean": 257.2,
#     "rollout/ep_rew_mean": 19.046804428100586,
#     "time/fps": 71,
#     "time/iterations": 79,
#     "time/time_elapsed": 407,
#     "train/baseline": -0.14658862352371216,
#     "train/entropy": 2.059657335281372,
#     "train/entropy_loss": -0.002059657359495759,
#     "train/grad_norm": 0.5676836967468262,
#     "train/loss": 0.24784418940544128,
#     "train/n_updates": 78,
#     "train/policy_gradient_loss": 0.13628318905830383,
#     "train/value_loss": 0.11362064629793167
# }
# {
#     "global_step": 30195,
#     "num_episodes": 82,
#     "rollout/ep_len_mean": 292.6,
#     "rollout/ep_rew_mean": 35.43476104736328,
#     "time/fps": 71,
#     "time/iterations": 82,
#     "time/time_elapsed": 421,
#     "train/baseline": -0.10421521961688995,
#     "train/entropy": 2.06203031539917,
#     "train/entropy_loss": -0.0020620303694158792,
#     "train/grad_norm": 0.7019965052604675,
#     "train/loss": 0.4081105887889862,
#     "train/n_updates": 81,
#     "train/policy_gradient_loss": 0.2875688970088959,
#     "train/value_loss": 0.12260372191667557
# }
# {
#     "global_step": 31361,
#     "num_episodes": 85,
#     "rollout/ep_len_mean": 334.7,
#     "rollout/ep_rew_mean": 47.70631408691406,
#     "time/fps": 71,
#     "time/iterations": 85,
#     "time/time_elapsed": 436,
#     "train/baseline": -0.07834024727344513,
#     "train/entropy": 2.061509370803833,
#     "train/entropy_loss": -0.0020615095272660255,
#     "train/grad_norm": 0.25203844904899597,
#     "train/loss": -0.18026606738567352,
#     "train/n_updates": 84,
#     "train/policy_gradient_loss": -0.27117452025413513,
#     "train/value_loss": 0.09296996891498566
# }
# {
#     "global_step": 32322,
#     "num_episodes": 87,
#     "rollout/ep_len_mean": 364.9,
#     "rollout/ep_rew_mean": 51.868896484375,
#     "time/fps": 71,
#     "time/iterations": 87,
#     "time/time_elapsed": 449,
#     "train/baseline": -0.06895717978477478,
#     "train/entropy": 2.061372995376587,
#     "train/entropy_loss": -0.0020613730885088444,
#     "train/grad_norm": 0.5939875841140747,
#     "train/loss": 0.23893660306930542,
#     "train/n_updates": 86,
#     "train/policy_gradient_loss": 0.2048400491476059,
#     "train/value_loss": 0.03615792095661163
# }
# {
#     "global_step": 33340,
#     "num_episodes": 89,
#     "rollout/ep_len_mean": 414.1,
#     "rollout/ep_rew_mean": 68.13436889648438,
#     "time/fps": 71,
#     "time/iterations": 89,
#     "time/time_elapsed": 463,
#     "train/baseline": -0.060981858521699905,
#     "train/entropy": 2.0620594024658203,
#     "train/entropy_loss": -0.002062059473246336,
#     "train/grad_norm": 0.7233753800392151,
#     "train/loss": 0.38263383507728577,
#     "train/n_updates": 88,
#     "train/policy_gradient_loss": 0.3287827968597412,
#     "train/value_loss": 0.05591310188174248
# }
# {
#     "global_step": 34504,
#     "num_episodes": 92,
#     "rollout/ep_len_mean": 430.9,
#     "rollout/ep_rew_mean": 58.42601776123047,
#     "time/fps": 71,
#     "time/iterations": 92,
#     "time/time_elapsed": 479,
#     "train/baseline": -0.05844959616661072,
#     "train/entropy": 2.058788537979126,
#     "train/entropy_loss": -0.0020587886683642864,
#     "train/grad_norm": 0.17478367686271667,
#     "train/loss": 0.18231192231178284,
#     "train/n_updates": 91,
#     "train/policy_gradient_loss": 0.10209693759679794,
#     "train/value_loss": 0.08227378129959106
# }
# {
#     "global_step": 35078,
#     "num_episodes": 94,
#     "rollout/ep_len_mean": 422.4,
#     "rollout/ep_rew_mean": 75.91802215576172,
#     "time/fps": 71,
#     "time/iterations": 94,
#     "time/time_elapsed": 488,
#     "train/baseline": -0.039570849388837814,
#     "train/entropy": 2.0614070892333984,
#     "train/entropy_loss": -0.002061407081782818,
#     "train/grad_norm": 0.3129802346229553,
#     "train/loss": -0.20820492506027222,
#     "train/n_updates": 93,
#     "train/policy_gradient_loss": -0.2584606111049652,
#     "train/value_loss": 0.05231709033250809
# }
# {
#     "global_step": 36063,
#     "num_episodes": 98,
#     "rollout/ep_len_mean": 324.4,
#     "rollout/ep_rew_mean": 68.37556457519531,
#     "time/fps": 71,
#     "time/iterations": 98,
#     "time/time_elapsed": 502,
#     "train/baseline": -0.061198994517326355,
#     "train/entropy": 2.051234245300293,
#     "train/entropy_loss": -0.002051234245300293,
#     "train/grad_norm": 1.1146990060806274,
#     "train/loss": 1.3937290906906128,
#     "train/n_updates": 97,
#     "train/policy_gradient_loss": 1.0729091167449951,
#     "train/value_loss": 0.3228711783885956
# }
# {
#     "global_step": 37107,
#     "num_episodes": 102,
#     "rollout/ep_len_mean": 260.3,
#     "rollout/ep_rew_mean": 58.58135986328125,
#     "time/fps": 71,
#     "time/iterations": 102,
#     "time/time_elapsed": 517,
#     "train/baseline": -0.03279200941324234,
#     "train/entropy": 2.050586462020874,
#     "train/entropy_loss": -0.002050586510449648,
#     "train/grad_norm": 0.537502646446228,
#     "train/loss": 0.09770183265209198,
#     "train/n_updates": 101,
#     "train/policy_gradient_loss": 0.05480055510997772,
#     "train/value_loss": 0.04495186358690262
# }
# {
#     "global_step": 38193,
#     "num_episodes": 106,
#     "rollout/ep_len_mean": 259.8,
#     "rollout/ep_rew_mean": 90.76338195800781,
#     "time/fps": 71,
#     "time/iterations": 106,
#     "time/time_elapsed": 532,
#     "train/baseline": -0.04482617229223251,
#     "train/entropy": 2.037132501602173,
#     "train/entropy_loss": -0.0020371326245367527,
#     "train/grad_norm": 1.2739030122756958,
#     "train/loss": 1.044810175895691,
#     "train/n_updates": 105,
#     "train/policy_gradient_loss": 0.8777115941047668,
#     "train/value_loss": 0.1691356599330902
# }
# {
#     "global_step": 39060,
#     "num_episodes": 109,
#     "rollout/ep_len_mean": 272.2,
#     "rollout/ep_rew_mean": 95.76869201660156,
#     "time/fps": 71,
#     "time/iterations": 109,
#     "time/time_elapsed": 544,
#     "train/baseline": -0.05154066160321236,
#     "train/entropy": 2.017397880554199,
#     "train/entropy_loss": -0.0020173978991806507,
#     "train/grad_norm": 0.6168228387832642,
#     "train/loss": 0.43987125158309937,
#     "train/n_updates": 108,
#     "train/policy_gradient_loss": 0.3742564916610718,
#     "train/value_loss": 0.06763216853141785
# }
# {
#     "global_step": 40238,
#     "num_episodes": 114,
#     "rollout/ep_len_mean": 261.0,
#     "rollout/ep_rew_mean": 127.4218978881836,
#     "time/fps": 71,
#     "time/iterations": 114,
#     "time/time_elapsed": 558,
#     "train/baseline": -0.014315832406282425,
#     "train/entropy": 2.019406318664551,
#     "train/entropy_loss": -0.0020194065291434526,
#     "train/grad_norm": 1.1722657680511475,
#     "train/loss": 0.818277895450592,
#     "train/n_updates": 113,
#     "train/policy_gradient_loss": 0.6430383920669556,
#     "train/value_loss": 0.17725889384746552
# }
# {
#     "global_step": 41215,
#     "num_episodes": 118,
#     "rollout/ep_len_mean": 251.6,
#     "rollout/ep_rew_mean": 300.69647216796875,
#     "time/fps": 72,
#     "time/iterations": 118,
#     "time/time_elapsed": 570,
#     "train/baseline": 0.20356373488903046,
#     "train/entropy": 1.752421498298645,
#     "train/entropy_loss": -0.0017524216091260314,
#     "train/grad_norm": 3.245114803314209,
#     "train/loss": 1.4163708686828613,
#     "train/n_updates": 117,
#     "train/policy_gradient_loss": 0.9917176365852356,
#     "train/value_loss": 0.4264056086540222
# }
# {
#     "global_step": 42100,
#     "num_episodes": 124,
#     "rollout/ep_len_mean": 186.2,
#     "rollout/ep_rew_mean": 609.5606079101562,
#     "time/fps": 72,
#     "time/iterations": 124,
#     "time/time_elapsed": 582,
#     "train/baseline": 1.7767822742462158,
#     "train/entropy": 0.5854832530021667,
#     "train/entropy_loss": -0.0005854832706972957,
#     "train/grad_norm": 1.4155423641204834,
#     "train/loss": 1.4465447664260864,
#     "train/n_updates": 123,
#     "train/policy_gradient_loss": 0.19097881019115448,
#     "train/value_loss": 1.2561514377593994
# }
# {
#     "global_step": 43050,
#     "num_episodes": 129,
#     "rollout/ep_len_mean": 171.2,
#     "rollout/ep_rew_mean": 559.744140625,
#     "time/fps": 72,
#     "time/iterations": 129,
#     "time/time_elapsed": 595,
#     "train/baseline": 0.640385627746582,
#     "train/entropy": 1.5721428394317627,
#     "train/entropy_loss": -0.001572142937220633,
#     "train/grad_norm": 4.312027931213379,
#     "train/loss": 1.2081292867660522,
#     "train/n_updates": 128,
#     "train/policy_gradient_loss": 0.5173673629760742,
#     "train/value_loss": 0.6923340559005737
# }
# {
#     "global_step": 44007,
#     "num_episodes": 134,
#     "rollout/ep_len_mean": 190.7,
#     "rollout/ep_rew_mean": 899.6173706054688,
#     "time/fps": 72,
#     "time/iterations": 134,
#     "time/time_elapsed": 609,
#     "train/baseline": 2.9189510345458984,
#     "train/entropy": 0.4591558873653412,
#     "train/entropy_loss": -0.00045915591181255877,
#     "train/grad_norm": 12.714448928833008,
#     "train/loss": 1.3717894554138184,
#     "train/n_updates": 133,
#     "train/policy_gradient_loss": -0.2706979215145111,
#     "train/value_loss": 1.6429466009140015
# }
# {
#     "global_step": 45110,
#     "num_episodes": 141,
#     "rollout/ep_len_mean": 160.6,
#     "rollout/ep_rew_mean": 1304.1075439453125,
#     "time/fps": 71,
#     "time/iterations": 141,
#     "time/time_elapsed": 626,
#     "train/baseline": 3.6293530464172363,
#     "train/entropy": 0.07236795872449875,
#     "train/entropy_loss": -7.236796227516606e-05,
#     "train/grad_norm": 217.20025634765625,
#     "train/loss": 16.355079650878906,
#     "train/n_updates": 140,
#     "train/policy_gradient_loss": 0.06346606463193893,
#     "train/value_loss": 16.291685104370117
# }
# {
#     "global_step": 46101,
#     "num_episodes": 147,
#     "rollout/ep_len_mean": 163.4,
#     "rollout/ep_rew_mean": 1914.864013671875,
#     "time/fps": 72,
#     "time/iterations": 147,
#     "time/time_elapsed": 640,
#     "train/baseline": 7.300065040588379,
#     "train/entropy": 0.007332983426749706,
#     "train/entropy_loss": -7.33298384147929e-06,
#     "train/grad_norm": 131.9290008544922,
#     "train/loss": 2.334041118621826,
#     "train/n_updates": 146,
#     "train/policy_gradient_loss": 0.11659078299999237,
#     "train/value_loss": 2.2174577713012695
# }
# Решено!

# %% [markdown]
# # 3 REINFORCE с разбиением на мини-батчи
# В предыдущих реализациях по данным одной собранной траетории стратегия обновлялась только один раз. Попробуем разбить траекторию на мини-батчи и обучаться на одной траектории в течение нескольких эпох. С одной стороны это должно привести к ускорению обучения, поскольку модели будут обновляться чаще. С другой стороны такая схема обучения отходит от on-policy режима.

# %%
class BatchedReturnBuffer(AverageReturnBuffer):
    def __init__(self, gamma: float = 0.99, device: Union[torch.device, str] = "cpu"):
        super().__init__(gamma, device)
        self.generator_ready = None

    def reset(self) -> None:
        super().reset()
        self.generator_ready = False

    def get(self, batch_size: Optional[Union[int, float]] = None) -> Generator[BufferSamples, None, None]:
        buffer_size = self.size()
        indices = np.random.permutation(buffer_size)
        if not self.generator_ready:
            self.observations = np.asarray(self.observations)
            self.actions = np.asarray(self.actions)
            self.returns = np.asarray(self.returns, dtype=np.float32)
            self.generator_ready = True

        if batch_size is None or math.isinf(batch_size):
            batch_size = buffer_size

        start_idx = 0
        while start_idx < buffer_size:
            yield self._get_samples(indices[start_idx: start_idx + batch_size])
            start_idx += batch_size

# %% [markdown]
# (3 балла)

# %%
class BatchedAverageReturnReinforce(Reinforce):
    def __init__(self, env: gym.Env, learning_rate: float = 2.5e-4, gamma: float = 0.99, ent_coef: float = 0.001,
                 max_grad_norm: float = 0.5, stats_window_size: int = 10, policy_class: Type[ReinforcePolicy] = ReinforcePolicy,
                 policy_kwargs: Optional[Dict[str, Any]] = None, buffer_class: Type[BatchedReturnBuffer] = BatchedReturnBuffer,
                 buffer_kwargs: Optional[Dict[str, Any]] = None, seed: Optional[int] = None,
                 device: Union[torch.device, str] = "cuda", batch_size: Union[int, float] = 64, n_epochs: int = 1):
        super().__init__(env, learning_rate, gamma, ent_coef, max_grad_norm, stats_window_size, policy_class, policy_kwargs,
                         buffer_class, buffer_kwargs, seed, device)
        self.batch_size = batch_size
        self.n_epochs = n_epochs

    def train(self) -> None:
        # В train выполняется self.n_epochs проходов по буферу.
        # Данные из буфера сэмплируются батчами размера self.batch_size: self.buffer.get(self.batch_size).
        # Тело функции аналогично методу train в AverageReturnBaselineReinforce,
        # единственное отличие - несколько эпох обучения и обучение на батчах.
        self.policy.set_training_mode(True)

        for _ in range(self.n_epochs):
            loss = torch.tensor(0.0, device=self.device)

            for rollout_data in self.buffer.get(self.batch_size):
                actions = rollout_data.actions.long()
                policy_output = self.policy.evaluate_actions(rollout_data.observations, actions)
                log_prob = policy_output['log_prob']
                entropy = policy_output['entropy']
                returns = rollout_data.returns

                # Получаем среднюю отдачу
                baseline = self.buffer.get_average_return()

                # Посчитать отдачи с учётом базового уровня
                returns = returns - baseline

                # Policy gradient loss
                policy_loss = -(returns * log_prob).mean()

                # Entropy loss
                entropy = torch.mean(entropy)
                entropy_loss = -self.ent_coef * entropy

                loss += (policy_loss + entropy_loss) / self.batch_size

            # Optimization step
            self.policy.optimizer.zero_grad()
            loss.backward()
            grad_norm = torch.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
            self.policy.optimizer.step()

        self._n_updates += 1

        self.log_dict = dict([
            ("train/entropy_loss", entropy_loss.item()), ("train/entropy", entropy.item()),
            ("train/policy_gradient_loss", policy_loss.item()), ("train/loss", loss.item()),
            ("train/grad_norm", grad_norm.item()), ("train/n_updates", self._n_updates),
            ("train/baseline", baseline)
        ])

# %% [markdown]
# ### Одна эпоха обучения

# %%
run_algorithm(
    algorithm_class=BatchedAverageReturnReinforce,
    algorithm_kwargs=dict(seed=0, batch_size=64, n_epochs=1),
    use_wandb=WANDB_IS_AVAILABLE,
    wandb_kwargs=dict(project='seminar_actor-critic', monitor_gym=True, name='reinforce_batch-epoch-1'),
    learn_kwargs=dict(max_timesteps=50000, log_interval=1000, expected_return=2000, save_checkpoint_interval=1000,
                    save_checkpoint_path='/content/drive/My Drive/seminar_actor-critic/reinforce_batch-epoch-1')
)
# Out:
# c:\Users\iRU\AppData\Local\Programs\Python\Python312\Lib\site-packages\vizdoom\gymnasium_wrapper\base_gymnasium_env.py:84: UserWarning: Detected screen format CRCGCB. Only RGB24 and GRAY8 are supported in the Gymnasium wrapper. Forcing RGB24.
#   warnings.warn(
# Using cuda device
# C:\Users\iRU\AppData\Local\Temp\ipykernel_5084\3336005168.py:79: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   self._last_obs = np.array(self._last_obs)
# C:\Users\iRU\AppData\Local\Temp\ipykernel_5084\3336005168.py:100: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   self._last_obs = np.array(new_obs)
# {
#     "global_step": 1375,
#     "num_episodes": 3,
#     "rollout/ep_len_mean": 458.3333333333333,
#     "rollout/ep_rew_mean": -50.81412124633789,
#     "time/fps": 75,
#     "time/iterations": 3,
#     "time/time_elapsed": 18,
#     "train/baseline": -0.1630199169741118,
#     "train/entropy": 2.079157590866089,
#     "train/entropy_loss": -0.0020791576243937016,
#     "train/grad_norm": 0.001999098341912031,
#     "train/loss": 0.01799141801893711,
#     "train/n_updates": 2,
#     "train/policy_gradient_loss": 0.07754276692867279
# }
# {
#     "global_step": 2184,
#     "num_episodes": 5,
#     "rollout/ep_len_mean": 436.8,
#     "rollout/ep_rew_mean": -54.99238204956055,
#     "time/fps": 71,
#     "time/iterations": 5,
#     "time/time_elapsed": 30,
#     "train/baseline": -0.11924439185111052,
#     "train/entropy": 2.0793304443359375,
#     "train/entropy_loss": -0.0020793306175619364,
#     "train/grad_norm": 0.0024466179311275482,
#     "train/loss": -0.00926489382982254,
#     "train/n_updates": 4,
#     "train/policy_gradient_loss": -0.3036709427833557
# }
# {
#     "global_step": 3181,
#     "num_episodes": 6,
#     "rollout/ep_len_mean": 530.1666666666666,
#     "rollout/ep_rew_mean": -60.09929275512695,
#     "time/fps": 71,
#     "time/iterations": 6,
#     "time/time_elapsed": 44,
#     "train/baseline": -0.12490222540428794,
#     "train/entropy": 2.079254388809204,
#     "train/entropy_loss": -0.0020792544819414616,
#     "train/grad_norm": 0.00228142156265676,
#     "train/loss": -0.004902348387986422,
#     "train/n_updates": 5,
#     "train/policy_gradient_loss": 0.037282973527908325
# }
# {
#     "global_step": 4303,
#     "num_episodes": 9,
#     "rollout/ep_len_mean": 478.1111111111111,
#     "rollout/ep_rew_mean": -60.41343688964844,
#     "time/fps": 73,
#     "time/iterations": 9,
#     "time/time_elapsed": 58,
#     "train/baseline": -0.12193354542233267,
#     "train/entropy": 2.0792341232299805,
#     "train/entropy_loss": -0.0020792342256754637,
#     "train/grad_norm": 0.0015369371976703405,
#     "train/loss": -0.0026618200354278088,
#     "train/n_updates": 8,
#     "train/policy_gradient_loss": -0.20098744332790375
# }
# {
#     "global_step": 5002,
#     "num_episodes": 11,
#     "rollout/ep_len_mean": 459.0,
#     "rollout/ep_rew_mean": -60.87067413330078,
#     "time/fps": 73,
#     "time/iterations": 11,
#     "time/time_elapsed": 67,
#     "train/baseline": -0.12669695667905348,
#     "train/entropy": 2.0792181491851807,
#     "train/entropy_loss": -0.0020792181603610516,
#     "train/grad_norm": 0.00240149418823421,
#     "train/loss": -0.007097119931131601,
#     "train/n_updates": 10,
#     "train/policy_gradient_loss": 0.0016218441305682063
# }
# {
#     "global_step": 6259,
#     "num_episodes": 14,
#     "rollout/ep_len_mean": 448.1,
#     "rollout/ep_rew_mean": -78.61328125,
#     "time/fps": 74,
#     "time/iterations": 14,
#     "time/time_elapsed": 83,
#     "train/baseline": -0.15540675644758645,
#     "train/entropy": 2.0792882442474365,
#     "train/entropy_loss": -0.0020792882423847914,
#     "train/grad_norm": 0.0010797311551868916,
#     "train/loss": -0.029274391010403633,
#     "train/n_updates": 13,
#     "train/policy_gradient_loss": -0.3555399775505066
# }
# {
#     "global_step": 7664,
#     "num_episodes": 17,
#     "rollout/ep_len_mean": 409.8,
#     "rollout/ep_rew_mean": -76.22071838378906,
#     "time/fps": 75,
#     "time/iterations": 17,
#     "time/time_elapsed": 101,
#     "train/baseline": -0.17078343084107378,
#     "train/entropy": 2.079216718673706,
#     "train/entropy_loss": -0.0020792167633771896,
#     "train/grad_norm": 0.001860814867541194,
#     "train/loss": -0.018590036779642105,
#     "train/n_updates": 16,
#     "train/policy_gradient_loss": -0.13421425223350525
# }
# {
#     "global_step": 9764,
#     "num_episodes": 18,
#     "rollout/ep_len_mean": 589.4,
#     "rollout/ep_rew_mean": -60.2855339050293,
#     "time/fps": 74,
#     "time/iterations": 18,
#     "time/time_elapsed": 130,
#     "train/baseline": -0.15477868293306016,
#     "train/entropy": 2.0792415142059326,
#     "train/entropy_loss": -0.0020792416762560606,
#     "train/grad_norm": 0.0013326583430171013,
#     "train/loss": 0.06083367019891739,
#     "train/n_updates": 17,
#     "train/policy_gradient_loss": 0.39938661456108093
# }
# {
#     "global_step": 10219,
#     "num_episodes": 19,
#     "rollout/ep_len_mean": 591.6,
#     "rollout/ep_rew_mean": -63.6234016418457,
#     "time/fps": 74,
#     "time/iterations": 19,
#     "time/time_elapsed": 137,
#     "train/baseline": -0.10901750799650323,
#     "train/entropy": 2.079247236251831,
#     "train/entropy_loss": -0.0020792472641915083,
#     "train/grad_norm": 0.006138618569821119,
#     "train/loss": 0.17802998423576355,
#     "train/n_updates": 18,
#     "train/policy_gradient_loss": 0.4109227955341339
# }
# {
#     "global_step": 11216,
#     "num_episodes": 20,
#     "rollout/ep_len_mean": 649.5,
#     "rollout/ep_rew_mean": -59.290199279785156,
#     "time/fps": 74,
#     "time/iterations": 20,
#     "time/time_elapsed": 151,
#     "train/baseline": -0.11524250867881641,
#     "train/entropy": 2.0791032314300537,
#     "train/entropy_loss": -0.00207910337485373,
#     "train/grad_norm": 0.0026001145597547293,
#     "train/loss": -0.032385509461164474,
#     "train/n_updates": 19,
#     "train/policy_gradient_loss": -0.08491720259189606
# }
# {
#     "global_step": 11909,
#     "num_episodes": 21,
#     "rollout/ep_len_mean": 690.7,
#     "rollout/ep_rew_mean": -54.3842887878418,
#     "time/fps": 73,
#     "time/iterations": 21,
#     "time/time_elapsed": 161,
#     "train/baseline": -0.10748252550052002,
#     "train/entropy": 2.07904314994812,
#     "train/entropy_loss": -0.0020790433045476675,
#     "train/grad_norm": 0.003733355551958084,
#     "train/loss": 0.04008859395980835,
#     "train/n_updates": 20,
#     "train/policy_gradient_loss": 0.05481633171439171
# }
# {
#     "global_step": 12788,
#     "num_episodes": 22,
#     "rollout/ep_len_mean": 721.2,
#     "rollout/ep_rew_mean": -29.2852840423584,
#     "time/fps": 73,
#     "time/iterations": 22,
#     "time/time_elapsed": 173,
#     "train/baseline": -0.10659111429026526,
#     "train/entropy": 2.0789859294891357,
#     "train/entropy_loss": -0.0020789860282093287,
#     "train/grad_norm": 0.0010140301892533898,
#     "train/loss": 0.004942792467772961,
#     "train/n_updates": 21,
#     "train/policy_gradient_loss": 0.08613746613264084
# }
# {
#     "global_step": 14888,
#     "num_episodes": 23,
#     "rollout/ep_len_mean": 899.6,
#     "rollout/ep_rew_mean": 40.53754425048828,
#     "time/fps": 73,
#     "time/iterations": 23,
#     "time/time_elapsed": 202,
#     "train/baseline": -0.0881843215563011,
#     "train/entropy": 2.0789780616760254,
#     "train/entropy_loss": -0.0020789781119674444,
#     "train/grad_norm": 0.004659752361476421,
#     "train/loss": 0.1129138171672821,
#     "train/n_updates": 22,
#     "train/policy_gradient_loss": 0.5674282312393188
# }
# {
#     "global_step": 15177,
#     "num_episodes": 24,
#     "rollout/ep_len_mean": 891.8,
#     "rollout/ep_rew_mean": 48.03314971923828,
#     "time/fps": 73,
#     "time/iterations": 24,
#     "time/time_elapsed": 207,
#     "train/baseline": -0.03846695649084637,
#     "train/entropy": 2.078538179397583,
#     "train/entropy_loss": -0.0020785382948815823,
#     "train/grad_norm": 0.009312870912253857,
#     "train/loss": 0.32234570384025574,
#     "train/n_updates": 23,
#     "train/policy_gradient_loss": 0.4793583154678345
# }
# {
#     "global_step": 15622,
#     "num_episodes": 25,
#     "rollout/ep_len_mean": 905.6,
#     "rollout/ep_rew_mean": 51.7398567199707,
#     "time/fps": 73,
#     "time/iterations": 25,
#     "time/time_elapsed": 213,
#     "train/baseline": -0.03963574784722246,
#     "train/entropy": 2.0766098499298096,
#     "train/entropy_loss": -0.002076609991490841,
#     "train/grad_norm": 0.005501893348991871,
#     "train/loss": -0.009172561578452587,
#     "train/n_updates": 24,
#     "train/policy_gradient_loss": 0.012091788463294506
# }
# {
#     "global_step": 16122,
#     "num_episodes": 27,
#     "rollout/ep_len_mean": 845.8,
#     "rollout/ep_rew_mean": 78.06156158447266,
#     "time/fps": 72,
#     "time/iterations": 27,
#     "time/time_elapsed": 221,
#     "train/baseline": -0.042506722006625544,
#     "train/entropy": 2.072080612182617,
#     "train/entropy_loss": -0.002072080736979842,
#     "train/grad_norm": 0.006298725493252277,
#     "train/loss": 0.00188658875413239,
#     "train/n_updates": 26,
#     "train/policy_gradient_loss": 0.029707180336117744
# }
# {
#     "global_step": 17215,
#     "num_episodes": 32,
#     "rollout/ep_len_mean": 442.7,
#     "rollout/ep_rew_mean": 167.4949951171875,
#     "time/fps": 72,
#     "time/iterations": 32,
#     "time/time_elapsed": 237,
#     "train/baseline": -0.010474932201683922,
#     "train/entropy": 1.717918872833252,
#     "train/entropy_loss": -0.0017179189017042518,
#     "train/grad_norm": 0.07959716767072678,
#     "train/loss": 0.14553876221179962,
#     "train/n_updates": 31,
#     "train/policy_gradient_loss": 2.4289612770080566
# }
# {
#     "global_step": 18033,
#     "num_episodes": 35,
#     "rollout/ep_len_mean": 241.1,
#     "rollout/ep_rew_mean": 104.92195892333984,
#     "time/fps": 72,
#     "time/iterations": 35,
#     "time/time_elapsed": 248,
#     "train/baseline": -0.014915877803135871,
#     "train/entropy": 2.055873394012451,
#     "train/entropy_loss": -0.0020558733958750963,
#     "train/grad_norm": 0.004585950169712305,
#     "train/loss": -0.05293941870331764,
#     "train/n_updates": 34,
#     "train/policy_gradient_loss": -0.8664724230766296
# }
# {
#     "global_step": 19150,
#     "num_episodes": 39,
#     "rollout/ep_len_mean": 262.8,
#     "rollout/ep_rew_mean": 75.822021484375,
#     "time/fps": 72,
#     "time/iterations": 39,
#     "time/time_elapsed": 263,
#     "train/baseline": -0.017901353397825948,
#     "train/entropy": 2.035421848297119,
#     "train/entropy_loss": -0.0020354220177978277,
#     "train/grad_norm": 0.007511017378419638,
#     "train/loss": -0.02686542458832264,
#     "train/n_updates": 38,
#     "train/policy_gradient_loss": -0.47345203161239624
# }
# {
#     "global_step": 20151,
#     "num_episodes": 43,
#     "rollout/ep_len_mean": 267.1,
#     "rollout/ep_rew_mean": 2.2161011695861816,
#     "time/fps": 72,
#     "time/iterations": 43,
#     "time/time_elapsed": 276,
#     "train/baseline": -0.02419360003582303,
#     "train/entropy": 2.0251212120056152,
#     "train/entropy_loss": -0.002025121357291937,
#     "train/grad_norm": 0.007436591200530529,
#     "train/loss": -0.031079668551683426,
#     "train/n_updates": 42,
#     "train/policy_gradient_loss": -0.4791073203086853
# }
# {
#     "global_step": 21358,
#     "num_episodes": 47,
#     "rollout/ep_len_mean": 271.1,
#     "rollout/ep_rew_mean": 83.9972915649414,
#     "time/fps": 72,
#     "time/iterations": 47,
#     "time/time_elapsed": 294,
#     "train/baseline": -0.009926618213400245,
#     "train/entropy": 1.9975029230117798,
#     "train/entropy_loss": -0.001997502986341715,
#     "train/grad_norm": 0.005212828516960144,
#     "train/loss": 0.03611660376191139,
#     "train/n_updates": 46,
#     "train/policy_gradient_loss": 0.4350254237651825
# }
# {
#     "global_step": 22118,
#     "num_episodes": 50,
#     "rollout/ep_len_mean": 269.1,
#     "rollout/ep_rew_mean": 146.21597290039062,
#     "time/fps": 72,
#     "time/iterations": 50,
#     "time/time_elapsed": 305,
#     "train/baseline": 0.01244283987400446,
#     "train/entropy": 1.9947197437286377,
#     "train/entropy_loss": -0.0019947197288274765,
#     "train/grad_norm": 0.009457978419959545,
#     "train/loss": 0.04396793991327286,
#     "train/n_updates": 49,
#     "train/policy_gradient_loss": 0.8258649706840515
# }
# {
#     "global_step": 23144,
#     "num_episodes": 54,
#     "rollout/ep_len_mean": 279.1,
#     "rollout/ep_rew_mean": 395.12432861328125,
#     "time/fps": 72,
#     "time/iterations": 54,
#     "time/time_elapsed": 319,
#     "train/baseline": 0.06626640768958003,
#     "train/entropy": 0.9171304702758789,
#     "train/entropy_loss": -0.0009171304991468787,
#     "train/grad_norm": 0.051408324390649796,
#     "train/loss": 0.11082925647497177,
#     "train/n_updates": 53,
#     "train/policy_gradient_loss": 1.553523063659668
# }
# {
#     "global_step": 24053,
#     "num_episodes": 58,
#     "rollout/ep_len_mean": 239.9,
#     "rollout/ep_rew_mean": 694.2423706054688,
#     "time/fps": 72,
#     "time/iterations": 58,
#     "time/time_elapsed": 331,
#     "train/baseline": 0.18628081203309543,
#     "train/entropy": 0.8738309741020203,
#     "train/entropy_loss": -0.0008738310425542295,
#     "train/grad_norm": 0.3162654638290405,
#     "train/loss": 0.4275120794773102,
#     "train/n_updates": 57,
#     "train/policy_gradient_loss": 4.832723617553711
# }
# {
#     "global_step": 25001,
#     "num_episodes": 62,
#     "rollout/ep_len_mean": 233.6,
#     "rollout/ep_rew_mean": 805.1806640625,
#     "time/fps": 72,
#     "time/iterations": 62,
#     "time/time_elapsed": 344,
#     "train/baseline": 0.22761987764692623,
#     "train/entropy": 0.7167222499847412,
#     "train/entropy_loss": -0.0007167222793214023,
#     "train/grad_norm": 0.05846744403243065,
#     "train/loss": 0.05461489036679268,
#     "train/n_updates": 61,
#     "train/policy_gradient_loss": 0.6724169850349426
# }
# {
#     "global_step": 26138,
#     "num_episodes": 69,
#     "rollout/ep_len_mean": 180.7,
#     "rollout/ep_rew_mean": 1389.2034912109375,
#     "time/fps": 72,
#     "time/iterations": 69,
#     "time/time_elapsed": 359,
#     "train/baseline": 0.4726877587383292,
#     "train/entropy": 0.04441433399915695,
#     "train/entropy_loss": -4.441433702595532e-05,
#     "train/grad_norm": 0.01713799685239792,
#     "train/loss": 0.006618383340537548,
#     "train/n_updates": 68,
#     "train/policy_gradient_loss": 0.01538647711277008
# }
# Решено!

# %% [markdown]
# ### Две эпохи обучения

# %%
run_algorithm(
    algorithm_class=BatchedAverageReturnReinforce,
    algorithm_kwargs=dict(seed=0, batch_size=64, n_epochs=2),
    use_wandb=WANDB_IS_AVAILABLE,
    wandb_kwargs=dict(project='seminar_actor-critic', monitor_gym=True, name='reinforce_batch-epoch-2'),
    learn_kwargs=dict(max_timesteps=50000, log_interval=1000, expected_return=2000, save_checkpoint_interval=1000,
                    save_checkpoint_path='/content/drive/My Drive/seminar_actor-critic/reinforce_batch-epoch-2')
)
# Out:
# Using cuda device
# C:\Users\iRU\AppData\Local\Temp\ipykernel_5084\3336005168.py:79: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   self._last_obs = np.array(self._last_obs)
# C:\Users\iRU\AppData\Local\Temp\ipykernel_5084\3336005168.py:100: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   self._last_obs = np.array(new_obs)
# {
#     "global_step": 1375,
#     "num_episodes": 3,
#     "rollout/ep_len_mean": 458.3333333333333,
#     "rollout/ep_rew_mean": -52.12679672241211,
#     "time/fps": 68,
#     "time/iterations": 3,
#     "time/time_elapsed": 20,
#     "train/baseline": -0.16636200765978035,
#     "train/entropy": 2.0792202949523926,
#     "train/entropy_loss": -0.002079220488667488,
#     "train/grad_norm": 0.002085841028019786,
#     "train/loss": 0.017334872856736183,
#     "train/n_updates": 2,
#     "train/policy_gradient_loss": 0.12621422111988068
# }
# {
#     "global_step": 2133,
#     "num_episodes": 5,
#     "rollout/ep_len_mean": 426.6,
#     "rollout/ep_rew_mean": -53.13086700439453,
#     "time/fps": 69,
#     "time/iterations": 5,
#     "time/time_elapsed": 30,
#     "train/baseline": -0.13147179009486476,
#     "train/entropy": 2.0793795585632324,
#     "train/entropy_loss": -0.0020793797448277473,
#     "train/grad_norm": 0.0014303072821348906,
#     "train/loss": -0.009293247945606709,
#     "train/n_updates": 4,
#     "train/policy_gradient_loss": 0.23152485489845276
# }
# {
#     "global_step": 3266,
#     "num_episodes": 6,
#     "rollout/ep_len_mean": 544.3333333333334,
#     "rollout/ep_rew_mean": -61.83823776245117,
#     "time/fps": 70,
#     "time/iterations": 6,
#     "time/time_elapsed": 46,
#     "train/baseline": -0.12436820238073266,
#     "train/entropy": 2.0793941020965576,
#     "train/entropy_loss": -0.002079394180327654,
#     "train/grad_norm": 0.0016824629856273532,
#     "train/loss": 0.006429931148886681,
#     "train/n_updates": 5,
#     "train/policy_gradient_loss": 0.12464505434036255
# }
# {
#     "global_step": 4331,
#     "num_episodes": 9,
#     "rollout/ep_len_mean": 481.22222222222223,
#     "rollout/ep_rew_mean": -65.24728393554688,
#     "time/fps": 70,
#     "time/iterations": 9,
#     "time/time_elapsed": 61,
#     "train/baseline": -0.12865807790778697,
#     "train/entropy": 2.079268217086792,
#     "train/entropy_loss": -0.002079268218949437,
#     "train/grad_norm": 0.0014384218957275152,
#     "train/loss": -0.028673464432358742,
#     "train/n_updates": 8,
#     "train/policy_gradient_loss": -0.4254245162010193
# }
# {
#     "global_step": 5484,
#     "num_episodes": 12,
#     "rollout/ep_len_mean": 463.0,
#     "rollout/ep_rew_mean": -67.59611511230469,
#     "time/fps": 71,
#     "time/iterations": 12,
#     "time/time_elapsed": 76,
#     "train/baseline": -0.15180614236925352,
#     "train/entropy": 2.0790324211120605,
#     "train/entropy_loss": -0.0020790325943380594,
#     "train/grad_norm": 0.0015553651610389352,
#     "train/loss": -0.03202255070209503,
#     "train/n_updates": 11,
#     "train/policy_gradient_loss": -0.408051460981369
# }
# {
#     "global_step": 6202,
#     "num_episodes": 13,
#     "rollout/ep_len_mean": 482.7,
#     "rollout/ep_rew_mean": -65.48930358886719,
#     "time/fps": 71,
#     "time/iterations": 13,
#     "time/time_elapsed": 87,
#     "train/baseline": -0.15211217472125776,
#     "train/entropy": 2.078859806060791,
#     "train/entropy_loss": -0.0020788598340004683,
#     "train/grad_norm": 0.0019832411780953407,
#     "train/loss": -0.0006288097938522696,
#     "train/n_updates": 12,
#     "train/policy_gradient_loss": 0.11712398380041122
# }
# {
#     "global_step": 7417,
#     "num_episodes": 16,
#     "rollout/ep_len_mean": 415.1,
#     "rollout/ep_rew_mean": -57.41010284423828,
#     "time/fps": 71,
#     "time/iterations": 16,
#     "time/time_elapsed": 104,
#     "train/baseline": -0.1425384471996798,
#     "train/entropy": 2.0775060653686523,
#     "train/entropy_loss": -0.0020775061566382647,
#     "train/grad_norm": 0.002958273747935891,
#     "train/loss": -0.026041746139526367,
#     "train/n_updates": 15,
#     "train/policy_gradient_loss": -0.2636004388332367
# }
# {
#     "global_step": 8059,
#     "num_episodes": 18,
#     "rollout/ep_len_mean": 412.2,
#     "rollout/ep_rew_mean": -46.009315490722656,
#     "time/fps": 70,
#     "time/iterations": 18,
#     "time/time_elapsed": 113,
#     "train/baseline": -0.12362182352602669,
#     "train/entropy": 2.035398483276367,
#     "train/entropy_loss": -0.0020353985019028187,
#     "train/grad_norm": 0.019570307806134224,
#     "train/loss": 0.050961919128894806,
#     "train/n_updates": 17,
#     "train/policy_gradient_loss": 1.4559674263000488
# }
# {
#     "global_step": 9037,
#     "num_episodes": 22,
#     "rollout/ep_len_mean": 355.3,
#     "rollout/ep_rew_mean": 82.77607727050781,
#     "time/fps": 70,
#     "time/iterations": 22,
#     "time/time_elapsed": 128,
#     "train/baseline": -0.09717567568871052,
#     "train/entropy": 1.7265653610229492,
#     "train/entropy_loss": -0.0017265654169023037,
#     "train/grad_norm": 0.05146091803908348,
#     "train/loss": 0.09225509315729141,
#     "train/n_updates": 21,
#     "train/policy_gradient_loss": 1.2797868251800537
# }
# {
#     "global_step": 10032,
#     "num_episodes": 28,
#     "rollout/ep_len_mean": 197.3,
#     "rollout/ep_rew_mean": 1465.522216796875,
#     "time/fps": 70,
#     "time/iterations": 28,
#     "time/time_elapsed": 141,
#     "train/baseline": 0.7211424003476129,
#     "train/entropy": 0.00039768312126398087,
#     "train/entropy_loss": -3.976831521868007e-07,
#     "train/grad_norm": 0.000892086885869503,
#     "train/loss": 1.3998502254253253e-05,
#     "train/n_updates": 27,
#     "train/policy_gradient_loss": 0.00029903327231295407
# }
# Решено!
